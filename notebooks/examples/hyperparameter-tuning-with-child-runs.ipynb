# %% [markdown]
# # MLflow with Optuna: Hyperparameter Optimization and Tracking
#
# A critical part of building production-grade models is ensuring that a given model's parameters are selected to create the best inference set possible. However, the sheer number of combinations and their resultant metrics can become overwhelming to track manually. That's where tools like MLflow and Optuna come into play.
#
# ### Objective:
# In this notebook, you'll learn how to integrate MLflow with Optuna for hyperparameter optimization. We'll guide you through the process of:
#
# * Setting up your environment with MLflow tracking.
# * Generating our training and evaluation data sets.
# * Defining a partial function that fits a machine learning model.
# * Using Optuna for hyperparameter tuning.
# * Leveraging child runs within MLflow to keep track of each iteration during the hyperparameter tuning process.
#
# ### Why Optuna?
# Optuna is an open-source hyperparameter optimization framework in Python. It provides an efficient approach to searching over hyperparameters, incorporating the latest research and techniques. With its integration into MLflow, every trial can be systematically recorded.
#
# ### Child Runs in MLflow:
# One of the core features we will be emphasizing is the concept of 'child runs' in MLflow. When performing hyperparameter tuning, each iteration (or trial) in Optuna can be considered a 'child run'. This allows us to group all the runs under one primary 'parent run', ensuring that the MLflow UI remains organized and interpretable. Each child run will track the specific hyperparameters used and the resulting metrics, providing a consolidated view of the entire optimization process.
#
# ### What's Ahead?
#
# **Data Preparation**: We'll start by loading and preprocessing our dataset.
#
# **Model Definition**: Defining a machine learning model that we aim to optimize.
#
# **Optuna Study**: Setting up an Optuna study to find the best hyperparameters for our model.
#
# **MLflow Integration**: Tracking each Optuna trial as a child run in MLflow.
#
# **Analysis**: Reviewing the tracked results in the MLflow UI.
#
# By the end of this notebook, you'll have hands-on experience in setting up an advanced hyperparameter tuning workflow, emphasizing best practices and clean organization using MLflow and Optuna.
#
# **Let's dive in!**

# %%
import math
from datetime import datetime, timedelta

import numpy as np
import optuna
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow

# %% [markdown]
# ### Configure the tracking server uri
#
# Depending on where you are running this notebook, your configuration may vary for how you initialize the interface with the MLflow Tracking Server.
#
# For this example, we're using a locally running tracking server, but other options are available (The easiest is to use the free managed service within [Databricks Free Trial](https://mlflow.org/docs/latest/getting-started/databricks-trial.html)).
#
# Please see [the guide to running notebooks here](https://www.mlflow.org/docs/latest/getting-started/running-notebooks/) for more information on setting the tracking server uri and configuring access to either managed or self-managed MLflow tracking servers.

# %%
# NOTE: review the links mentioned above for guidance on connecting to a managed tracking server, such as the Databricks managed MLflow

mlflow.set_tracking_uri("http://localhost:5000")

# %% [markdown]
# ### Generate our synthetic training data
#
# If you've followed along with the introductory tutorial "Logging your first model with MLflow", then you're familiar with the apples sales data generator that we created for that tutorial.
#
# Here, we're expanding upon the data to create a slightly more complex dataset that should have improved correlation effects between the features and the target variable (the demand).

# %%
def generate_apple_sales_data_with_promo_adjustment(
    base_demand: int = 1000,
    n_rows: int = 5000,
    competitor_price_effect: float = -50.0,
):
    """
    Generates a synthetic dataset for predicting apple sales demand with multiple
    influencing factors.

    This function creates a pandas DataFrame with features relevant to apple sales.
    The features include date, average_temperature, rainfall, weekend flag, holiday flag,
    promotional flag, price_per_kg, competitor's price, marketing intensity, stock availability,
    and the previous day's demand. The target variable, 'demand', is generated based on a
    combination of these features with some added noise.

    Args:
        base_demand (int, optional): Base demand for apples. Defaults to 1000.
        n_rows (int, optional): Number of rows (days) of data to generate. Defaults to 5000.
        competitor_price_effect (float, optional): Effect of competitor's price being lower
                                                   on our sales. Defaults to -50.

    Returns:
        pd.DataFrame: DataFrame with features and target variable for apple sales prediction.

    Example:
        >>> df = generate_apple_sales_data_with_promo_adjustment(base_demand=1200, n_rows=6000)
        >>> df.head()
    """

    # Set seed for reproducibility
    np.random.seed(9999)

    # Create date range
    dates = [datetime.now() - timedelta(days=i) for i in range(n_rows)]
    dates.reverse()

    # Generate features
    df = pd.DataFrame(
        {
            "date": dates,
            "average_temperature": np.random.uniform(10, 35, n_rows),
            "rainfall": np.random.exponential(5, n_rows),
            "weekend": [(date.weekday() >= 5) * 1 for date in dates],
            "holiday": np.random.choice([0, 1], n_rows, p=[0.97, 0.03]),
            "price_per_kg": np.random.uniform(0.5, 3, n_rows),
            "month": [date.month for date in dates],
        }
    )

    # Introduce inflation over time (years)
    df["inflation_multiplier"] = 1 + (df["date"].dt.year - df["date"].dt.year.min()) * 0.03

    # Incorporate seasonality due to apple harvests
    df["harvest_effect"] = np.sin(2 * np.pi * (df["month"] - 3) / 12) + np.sin(
        2 * np.pi * (df["month"] - 9) / 12
    )

    # Modify the price_per_kg based on harvest effect
    df["price_per_kg"] = df["price_per_kg"] - df["harvest_effect"] * 0.5

    # Adjust promo periods to coincide with periods lagging peak harvest by 1 month
    peak_months = [4, 10]  # months following the peak availability
    df["promo"] = np.where(
        df["month"].isin(peak_months),
        1,
        np.random.choice([0, 1], n_rows, p=[0.85, 0.15]),
    )

    # Generate target variable based on features
    base_price_effect = -df["price_per_kg"] * 50
    seasonality_effect = df["harvest_effect"] * 50
    promo_effect = df["promo"] * 200

    df["demand"] = (
        base_demand
        + base_price_effect
        + seasonality_effect
        + promo_effect
        + df["weekend"] * 300
        + np.random.normal(0, 50, n_rows)
    ) * df["inflation_multiplier"]  # adding random noise

    # Add previous day's demand
    df["previous_days_demand"] = df["demand"].shift(1)
    df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row

    # Introduce competitor pricing
    df["competitor_price_per_kg"] = np.random.uniform(0.5, 3, n_rows)
    df["competitor_price_effect"] = (
        df["competitor_price_per_kg"] < df["price_per_kg"]
    ) * competitor_price_effect

    # Stock availability based on past sales price (3 days lag with logarithmic decay)
    log_decay = -np.log(df["price_per_kg"].shift(3) + 1) + 2
    df["stock_available"] = np.clip(log_decay, 0.7, 1)

    # Marketing intensity based on stock availability
    # Identify where stock is above threshold
    high_stock_indices = df[df["stock_available"] > 0.95].index

    # For each high stock day, increase marketing intensity for the next week
    for idx in high_stock_indices:
        df.loc[idx : min(idx + 7, n_rows - 1), "marketing_intensity"] = np.random.uniform(0.7, 1)

    # If the marketing_intensity column already has values, this will preserve them;
    #  if not, it sets default values
    fill_values = pd.Series(np.random.uniform(0, 0.5, n_rows), index=df.index)
    df["marketing_intensity"].fillna(fill_values, inplace=True)

    # Adjust demand with new factors
    df["demand"] = df["demand"] + df["competitor_price_effect"] + df["marketing_intensity"]

    # Drop temporary columns
    df.drop(
        columns=[
            "inflation_multiplier",
            "harvest_effect",
            "month",
            "competitor_price_effect",
            "stock_available",
        ],
        inplace=True,
    )

    return df

# %%
df = generate_apple_sales_data_with_promo_adjustment(base_demand=1_000, n_rows=5000)
df
# Out:
# /tmp/ipykernel_199/1129670120.py:85: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row
#                            date  average_temperature   rainfall  weekend  \
# 0    2011-10-02 01:15:37.408331            30.584727   1.199291        1
# 1    2011-10-03 01:15:37.408331            15.465069   1.037626        0
# 2    2011-10-04 01:15:37.408330            10.786525   5.656089        0
# 3    2011-10-05 01:15:37.408330            23.648154  12.030937        0
# 4    2011-10-06 01:15:37.408329            13.861391   4.303812        0
# ...                         ...                  ...        ...      ...
# 4995 2025-06-05 01:15:37.404897            21.643051   3.821656        0
# 4996 2025-06-06 01:15:37.404896            13.808813   1.080603        0
# 4997 2025-06-07 01:15:37.404895            11.698227   1.911000        1
# 4998 2025-06-08 01:15:37.404893            18.052081   1.000521        1
# 4999 2025-06-09 01:15:37.404888            17.017294   0.650213        0
#
#       holiday  price_per_kg  promo       demand  previous_days_demand  \
# 0           0      1.726258      1  1351.375336           1351.276659
# 1           0      0.576471      1  1106.855943           1351.276659
# 2           0      2.513328      1  1008.304909           1106.836626
# 3           0      1.839225      1   999.833810           1057.895424
# 4           0      1.531772      1  1183.949061           1048.961007
# ...       ...           ...    ...          ...                   ...
# 4995        0      2.391010      0  1165.882437           1170.799278
# 4996        1      0.898693      0  1312.870527           1215.125948
# 4997        0      2.839860      0  1413.065524           1312.128382
# 4998        0      1.188440      0  1823.886638           1462.323379
# 4999        0      2.131694      0  1289.584771           1823.144493
#
#       competitor_price_per_kg  marketing_intensity
# 0                    1.935346             0.098677
# 1                    2.344720             0.019318
# 2                    0.998803             0.409485
# 3                    0.761740             0.872803
# 4                    2.123436             0.820779
# ...                       ...                  ...
# 4995                 1.504432             0.756489
# 4996                 1.343586             0.742145
# 4997                 2.771896             0.742145
# 4998                 2.564075             0.742145
# 4999                 0.785727             0.833140
#
# [5000 rows x 11 columns]

# %% [markdown]
# ### Examining Feature-Target Correlations
#
# Before delving into the model building process, it's essential to understand the relationships between our features and the target variable. The upcoming function will display a plot indicating the correlation coefficient for each feature in relation to the target. Here's why this step is crucial:
#
# 1. **Avoiding Data Leakage**: We must ensure that no feature perfectly correlates with the target (a correlation coefficient of 1.0). If such a correlation exists, it's a sign that our dataset might be "leaking" information about the target. Using such data for hyperparameter tuning would mislead the model, as it could easily achieve a perfect score without genuinely learning the underlying patterns.
#
# 2. **Ensuring Meaningful Relationships**: Ideally, our features should have some degree of correlation with the target. If all features have correlation coefficients close to zero, it suggests a weak linear relationship. Although this doesn't automatically render the features useless, it does introduce challenges:
#     * *Predictive Power*: The model might struggle to make accurate predictions.
#     * *Overfitting Risk*: With weak correlations, there's a heightened risk of the model fitting to noise rather than genuine patterns, leading to overfitting.
#     * *Complexity*: Demonstrating non-linear relationships or interactions between features would necessitate more intricate visualizations and evaluations.
# 3. **Auditing and Traceability**: Logging this correlation visualization with our main MLflow run ensures traceability. It provides a snapshot of the data characteristics at the time of the model training, which is invaluable for auditing and replicability purposes.
#
# As we proceed, remember that while understanding correlations is a powerful tool, it's just one piece of the puzzle. Let's visualize these relationships to gain more insights!

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_correlation_with_demand(df, save_path=None):  # noqa: D417
    """
    Plots the correlation of each variable in the dataframe with the 'demand' column.

    Args:
    - df (pd.DataFrame): DataFrame containing the data, including a 'demand' column.
    - save_path (str, optional): Path to save the generated plot. If not specified, plot won't be saved.

    Returns:
    - None (Displays the plot on a Jupyter window)
    """

    # Compute correlations between all variables and 'demand'
    correlations = df.corr()["demand"].drop("demand").sort_values()

    # Generate a color palette from red to green
    colors = sns.diverging_palette(10, 130, as_cmap=True)
    color_mapped = correlations.map(colors)

    # Set Seaborn style
    sns.set_style(
        "whitegrid", {"axes.facecolor": "#c2c4c2", "grid.linewidth": 1.5}
    )  # Light grey background and thicker grid lines

    # Create bar plot
    fig = plt.figure(figsize=(12, 8))
    plt.barh(correlations.index, correlations.values, color=color_mapped)

    # Set labels and title with increased font size
    plt.title("Correlation with Demand", fontsize=18)
    plt.xlabel("Correlation Coefficient", fontsize=16)
    plt.ylabel("Variable", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(axis="x")

    plt.tight_layout()

    # Save the plot if save_path is specified
    if save_path:
        plt.savefig(save_path, format="png", dpi=600)

    # prevent matplotlib from displaying the chart every time we call this function
    plt.close(fig)

    return fig


# Test the function
correlation_plot = plot_correlation_with_demand(df, save_path="correlation_plot.png")

# %% [markdown]
# #### Investigating Feature Correlation with the Target Variable
#
# In the code above, we've intentionally disabled the automatic display of the plot generated by Matplotlib. During machine learning experimentation, it's often not useful to display figures directly within the notebook for several reasons. Instead, we aim to associate this plot with the results of an iterative experiment run. To achieve this, we'll save the plot to our MLflow tracking system. This provides us with a detailed record, linking the state of the dataset to the logged model, its parameters, and performance metrics.
#
# ##### Why Not Display Plots Directly in the Notebook?
#
# Choosing not to display plots within the notebook is a deliberate decision, and the reasons are multiple. Some of the key points include:
#
# - **Ephemerality of Notebooks**: Notebooks are inherently transient; they are not designed to be a permanent record of your work.
#
# - **Risk of Obsolescence**: If you rerun portions of your notebook, the plot displayed could become outdated or misleading, posing a risk when interpreting results.
#
# - **Loss of Previous State**: If you happen to rerun the entire notebook, the plot will be lost. While some plugins can recover previous cell states, setting this up can be cumbersome and time-consuming.
#
# In contrast, logging the plot to MLflow ensures that we have a permanent, easily accessible record that correlates directly with other experiment data. This is invaluable for maintaining the integrity and reproducibility of your machine learning experiments.
#
# ##### Displaying the Plot for This Guide
#
# For the purposes of this guide, we'll still take a moment to examine the plot. We can do this by explicitly calling the figure object we've returned from our function.

# %%
correlation_plot

# %% [markdown]
# #### Visualizing Model Residuals for Diagnostic Insights
#
# The `plot_residuals` function serves to visualize the residuals—the differences between the model's predictions and the actual values in the validation set. Residual plots are crucial diagnostic tools in machine learning, as they can reveal patterns that suggest our model is either failing to capture some aspect of the data or that there's a systematic issue with the model itself.
#
# ##### Why Residual Plots?
#
# Residual plots offer several advantages:
#
# - **Identifying Bias**: If residuals show a trend (not centered around zero), it might indicate that your model is systematically over- or under-predicting the target variable.
#
# - **Heteroskedasticity**: Varying spread of residuals across the range of the predicted values can indicate 'Heteroskedasticity,' which can violate assumptions in some modeling techniques.
#
# - **Outliers**: Points far away from the zero line can be considered as outliers and might warrant further investigation.
#
# ##### Auto-saving the Plot
#
# Just like with the correlation plot, this function allows you to save the residual plot to a specific path. This feature aligns with our broader strategy of logging important figures to MLflow for more effective model tracking and auditing.
#
# ##### Plot Structure
#
# In the scatter plot, each point represents the residual for a specific observation in the validation set. The red horizontal line at zero serves as a reference, indicating where residuals would lie if the model's predictions were perfect.
#
# For the sake of this guide, we will be generating this plot, but not examining it until later when we see it within the MLflow UI.

# %%
def plot_residuals(model, dvalid, valid_y, save_path=None):  # noqa: D417
    """
    Plots the residuals of the model predictions against the true values.

    Args:
    - model: The trained XGBoost model.
    - dvalid (xgb.DMatrix): The validation data in XGBoost DMatrix format.
    - valid_y (pd.Series): The true values for the validation set.
    - save_path (str, optional): Path to save the generated plot. If not specified, plot won't be saved.

    Returns:
    - None (Displays the residuals plot on a Jupyter window)
    """

    # Predict using the model
    preds = model.predict(dvalid)

    # Calculate residuals
    residuals = valid_y - preds

    # Set Seaborn style
    sns.set_style("whitegrid", {"axes.facecolor": "#c2c4c2", "grid.linewidth": 1.5})

    # Create scatter plot
    fig = plt.figure(figsize=(12, 8))
    plt.scatter(valid_y, residuals, color="blue", alpha=0.5)
    plt.axhline(y=0, color="r", linestyle="-")

    # Set labels, title and other plot properties
    plt.title("Residuals vs True Values", fontsize=18)
    plt.xlabel("True Values", fontsize=16)
    plt.ylabel("Residuals", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(axis="y")

    plt.tight_layout()

    # Save the plot if save_path is specified
    if save_path:
        plt.savefig(save_path, format="png", dpi=600)

    # Show the plot
    plt.close(fig)

    return fig

# %% [markdown]
# #### Understanding Feature Importance with XGBoost
#
# The `plot_feature_importance` function is designed to visualize the importance of each feature used in our XGBoost model. Understanding feature importance can offer critical insights into the model's decision-making process and can aid in feature selection, engineering, and interpretation.
#
# ##### Types of Feature Importance
#
# XGBoost offers multiple ways to interpret feature importance. This function supports:
#
# - **Weight**: Number of times a feature appears in a tree across the ensemble of trees (for `gblinear` booster).
# - **Gain**: Average gain (or improvement to the model) of the feature when it is used in trees (for other booster types).
#
# We automatically select the appropriate importance type based on the booster used in the XGBoost model.
#
# ##### Why Feature Importance Matters
#
# Understanding feature importance offers several advantages:
#
# - **Interpretability**: Knowing which features are most influential helps us understand the model better.
# - **Feature Selection**: Unimportant features can potentially be dropped to simplify the model.
# - **Domain Understanding**: Aligns the model's importance scale with domain-specific knowledge or intuition.
#
# ##### Saving and Accessing the Plot
#
# This function returns a Matplotlib figure object that you can further manipulate or save. Like the previous plots, it is advisable to log this plot in MLflow for an immutable record of your model's interpretive characteristics.
#
# ##### Navigating the Plot
#
# In the resulting plot, each bar represents a feature used in the model. The length of the bar corresponds to the feature's importance, as calculated by the selected importance type.
#
# We need a model to be trained in order to generate this plot. As such, we'll be generating, but not displaying the plot when we train the model. The resulting figure will be logged to MLflow and visible within the UI.

# %%
def plot_feature_importance(model, booster):  # noqa: D417
    """
    Plots feature importance for an XGBoost model.

    Args:
    - model: A trained XGBoost model

    Returns:
    - fig: The matplotlib figure object
    """
    fig, ax = plt.subplots(figsize=(10, 8))
    importance_type = "weight" if booster == "gblinear" else "gain"
    xgb.plot_importance(
        model,
        importance_type=importance_type,
        ax=ax,
        title=f"Feature Importance based on {importance_type}",
    )
    plt.tight_layout()
    plt.close(fig)

    return fig

# %% [markdown]
# ### Setting Up the MLflow Experiment
#
# Before we start our hyperparameter tuning process, we need to designate a specific "experiment" within MLflow to track and log our results. An experiment in MLflow is essentially a named set of runs. Each run within an experiment tracks its own parameters, metrics, tags, and artifacts.
#
# #### Why create a new experiment?
#
# 1. **Organization**: It helps in keeping our runs organized under a specific task or project, making it easier to compare and analyze results.
# 2. **Isolation**: By isolating different tasks or projects into separate experiments, we prevent accidental overwrites or misinterpretations of results.
#
# The `get_or_create_experiment` function we've defined below aids in this process. It checks if an experiment with the specified name already exists. If yes, it retrieves its ID. If not, it creates a new experiment and returns its ID.
#
# #### How will we use the experiment_id?
# The retrieved or created experiment_id becomes crucial when we initiate our hyperparameter tuning. As we start the parent run for tuning, the experiment_id ensures that the run, along with its nested child runs, gets logged under the correct experiment. It provides a structured way to navigate, compare, and analyze our tuning results within the MLflow UI.
#
# When we want to try additional parameter ranges, different parameters, or a slightly modified dataset, we can use this Experiment to log all parent runs to keep our MLflow Tracking UI clean and easy to navigate.
#
# Let's proceed and set up our experiment!

# %%
def get_or_create_experiment(experiment_name):
    """
    Retrieve the ID of an existing MLflow experiment or create a new one if it doesn't exist.

    This function checks if an experiment with the given name exists within MLflow.
    If it does, the function returns its ID. If not, it creates a new experiment
    with the provided name and returns its ID.

    Parameters:
    - experiment_name (str): Name of the MLflow experiment.

    Returns:
    - str: ID of the existing or newly created MLflow experiment.
    """

    if experiment := mlflow.get_experiment_by_name(experiment_name):
        return experiment.experiment_id
    else:
        return mlflow.create_experiment(experiment_name)

# %% [markdown]
# #### Create an experiment for our hyperparameter tuning runs

# %%
experiment_id = get_or_create_experiment("Apples Demand")

# %% [markdown]
# We can view the `experiment_id` that was either generated or fetched to see how this unique reference key looks. The value generated here is also visible within the MLflow UI.

# %%
experiment_id
# Out:
# '671527703213651607'

# %% [markdown]
# #### Setting Up MLflow and Data Preprocessing for Model Training
#
# This section of the code accomplishes two major tasks: initializing an MLflow experiment for usage in run tracking and preparing the dataset for model training and validation.
#
# ##### MLflow Initialization
#
# We start by setting the MLflow experiment using the `set_experiment` function. The `experiment_id` serves as a unique identifier for the experiment, allowing us to segregate and manage different runs and their associated data efficiently.
#
# ##### Data Preprocessing
#
# The next steps involve preparing the dataset for model training:
#
# 1. **Feature Selection**: We drop the columns 'date' and 'demand' from our DataFrame, retaining only the feature columns in `X`.
#
# 2. **Target Variable**: The 'demand' column is designated as our target variable `y`.
#
# 3. **Data Splitting**: We split the dataset into training (`train_x`, `train_y`) and validation (`valid_x`, `valid_y`) sets using a 75-25 split.
#
# 4. **XGBoost Data Format**: Finally, we convert the training and validation datasets into XGBoost's DMatrix format. This optimized data structure speeds up the training process and is required for using XGBoost's advanced functionalities.
#
# ##### Why These Steps Matter
#
# - **MLflow Tracking**: Initializing the MLflow experiment ensures that all subsequent model runs, metrics, and artifacts are logged under the same experiment, making it easier to compare and analyze different models. While we are using the ``fluent API`` to do this here, you can also specify the ``experiment_id`` within a ``start_run()`` context.
#
# - **Data Preparation**: Properly preparing your data ensures that the model training process will proceed without issues and that the results will be as accurate as possible.
#
# In the next steps, we'll proceed to model training and evaluation, and all these preparation steps will come into play.

# %%
# Set the current active MLflow experiment
mlflow.set_experiment(experiment_id=experiment_id)

# Preprocess the dataset
X = df.drop(columns=["date", "demand"])
y = df["demand"]
train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.25)
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x, label=valid_y)

# %% [markdown]
# #### Hyperparameter Tuning and Model Training using Optuna and MLflow
#
# The `objective` function serves as the core of our hyperparameter tuning process using Optuna. Additionally, it trains an XGBoost model using the selected hyperparameters and logs metrics and parameters to MLflow.
#
# ##### MLflow Nested Runs
#
# The function starts a new nested run in MLflow. Nested runs are useful for organizing hyperparameter tuning experiments as they allow you to group individual runs under a parent run.
#
# ##### Defining Hyperparameters
#
# Optuna's `trial.suggest_*` methods are used to define a range of possible values for hyperparameters. Here's what each hyperparameter does:
#
# - `objective` and `eval_metric`: Define the loss function and evaluation metric.
# - `booster`: Type of boosting to be used (`gbtree`, `gblinear`, or `dart`).
# - `lambda` and `alpha`: Regularization parameters.
# - Additional parameters like `max_depth`, `eta`, and `gamma` are specific to tree-based models (`gbtree` and `dart`).
#
# ##### Model Training
#
# An XGBoost model is trained using the chosen hyperparameters and the preprocessed training dataset (`dtrain`). Predictions are made on the validation set (`dvalid`), and the mean squared error (`mse`) is calculated.
#
# ##### Logging with MLflow
#
# All the selected hyperparameters and metrics (`mse` and `rmse`) are logged to MLflow for later analysis and comparison.
#
# - `mlflow.log_params`: Logs the hyperparameters.
# - `mlflow.log_metric`: Logs the metrics.
#
# ##### Why This Function is Important
#
# - **Automated Tuning**: Optuna automates the process of finding the best hyperparameters.
# - **Experiment Tracking**: MLflow allows us to keep track of each run's hyperparameters and performance metrics, making it easier to analyze, compare, and reproduce experiments later.
#
# In the next step, this objective function will be used by Optuna to find the optimal set of hyperparameters for our XGBoost model.

# %% [markdown]
# #### Housekeeping: Streamlining Logging for Optuna Trials
#
# As we embark on our hyperparameter tuning journey with Optuna, it's essential to understand that the process can generate a multitude of runs. In fact, so many that the standard output (stdout) from the default logger can quickly become inundated, producing pages upon pages of log reports.
#
# While the verbosity of the default logging configuration is undeniably valuable during the code development phase, initiating a full-scale trial can result in an overwhelming amount of information. Considering this, logging every single detail to stdout becomes less practical, especially when we have dedicated tools like MLflow to meticulously track our experiments.
#
# To strike a balance, we'll utilize callbacks to tailor our logging behavior.
#
# ##### Implementing a Logging Callback:
#
# The callback we're about to introduce will modify the default reporting behavior. Instead of logging every trial, we'll only receive updates when a new hyperparameter combination yields an improvement over the best metric value recorded thus far.
#
# This approach offers two salient benefits:
#
# 1. **Enhanced Readability**: By filtering out the extensive log details and focusing only on the trials that show improvement, we can gauge the efficacy of our hyperparameter search. For instance, if we observe a diminishing frequency of 'best result' reports early on, it might suggest that fewer iterations would suffice to pinpoint an optimal hyperparameter set. On the other hand, a consistent rate of improvement might indicate that our feature set requires further refinement.
#
# 2. **Progress Indicators**: Especially pertinent for extensive trials that span hours or even days, receiving periodic updates provides assurance that the process is still in motion. These 'heartbeat' notifications affirm that our system is diligently at work, even if it's not flooding stdout with every minute detail.
#
# Moreover, MLflow's user interface (UI) complements this strategy. As each trial concludes, MLflow logs the child run, making it accessible under the umbrella of the parent run.
#
# In the ensuing code, we:
#
# 1. Adjust Optuna's logging level to report only errors, ensuring a decluttered stdout.
# 2. Define a `champion_callback` function, tailored to log only when a trial surpasses the previously recorded best metric.
#
# Let's dive into the implementation:

# %%
# override Optuna's default logging to ERROR only
optuna.logging.set_verbosity(optuna.logging.ERROR)

# define a logging callback that will report on only new challenger parameter configurations if a
# trial has usurped the state of 'best conditions'


def champion_callback(study, frozen_trial):
    """
    Logging callback that will report when a new trial iteration improves upon existing
    best trial values.

    Note: This callback is not intended for use in distributed computing systems such as Spark
    or Ray due to the micro-batch iterative implementation for distributing trials to a cluster's
    workers or agents.
    The race conditions with file system state management for distributed trials will render
    inconsistent values with this callback.
    """

    winner = study.user_attrs.get("winner", None)

    if study.best_value and winner != study.best_value:
        study.set_user_attr("winner", study.best_value)
        if winner:
            improvement_percent = (abs(winner - study.best_value) / study.best_value) * 100
            print(
                f"Trial {frozen_trial.number} achieved value: {frozen_trial.value} with "
                f"{improvement_percent: .4f}% improvement"
            )
        else:
            print(f"Initial trial {frozen_trial.number} achieved value: {frozen_trial.value}")

# %%
def objective(trial):
    with mlflow.start_run(nested=True):
        # Define hyperparameters
        params = {
            "objective": "reg:squarederror",
            "eval_metric": "rmse",
            "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
            "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
            "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        }

        if params["booster"] == "gbtree" or params["booster"] == "dart":
            params["max_depth"] = trial.suggest_int("max_depth", 1, 9)
            params["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
            params["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
            params["grow_policy"] = trial.suggest_categorical(
                "grow_policy", ["depthwise", "lossguide"]
            )

        # Train XGBoost model
        bst = xgb.train(params, dtrain)
        preds = bst.predict(dvalid)
        error = mean_squared_error(valid_y, preds)

        # Log to MLflow
        mlflow.log_params(params)
        mlflow.log_metric("mse", error)
        mlflow.log_metric("rmse", math.sqrt(error))

    return error

# %% [markdown]
# #### Orchestrating Hyperparameter Tuning, Model Training, and Logging with MLflow
#
# This section of the code serves as the orchestration layer, bringing together Optuna for hyperparameter tuning and MLflow for experiment tracking.
#
# ##### Initiating Parent Run
#
# We begin by starting a parent MLflow run with the name "Best Run". All subsequent operations, including Optuna's trials, are nested under this parent run, providing a structured way to organize our experiments.
#
# ##### Hyperparameter Tuning with Optuna
#
# - `study = optuna.create_study(direction='minimize')`: We create an Optuna study object aiming to minimize our objective function.
# - `study.optimize(objective, n_trials=10)`: The `objective` function is optimized over 10 trials.
#
# ##### Logging Best Parameters and Metrics
#
# After Optuna finds the best hyperparameters, we log these, along with the best mean squared error (`mse`) and root mean squared error (`rmse`), to MLflow.
#
# ##### Logging Additional Metadata
#
# Using `mlflow.set_tags`, we log additional metadata like the project name, optimization engine, model family, and feature set version. This helps in better categorizing and understanding the context of the model run.
#
# ##### Model Training and Artifact Logging
#
# - We train an XGBoost model using the best hyperparameters.
# - Various plots—correlation with demand, feature importance, and residuals—are generated and logged as artifacts in MLflow.
#
# ##### Model Serialization and Logging
#
# Finally, the trained model is logged to MLflow using `mlflow.xgboost.log_model`, along with an example input and additional metadata. The model is stored in a specified artifact path and its URI is retrieved.
#
# ##### Why This Block is Crucial
#
# - **End-to-End Workflow**: This code block represents an end-to-end machine learning workflow, from hyperparameter tuning to model evaluation and logging.
# - **Reproducibility**: All details about the model, including hyperparameters, metrics, and visual diagnostics, are logged, ensuring that the experiment is fully reproducible.
# - **Analysis and Comparison**: With all data logged in MLflow, it becomes easier to analyze the performance of various runs and choose the best model for deployment.
#
# In the next steps, we'll explore how to retrieve and use the logged model for inference.

# %% [markdown]
# #### Setting a Descriptive Name for the Model Run
#
# Before proceeding with model training and hyperparameter tuning, it's beneficial to assign a descriptive name to our MLflow run. This name serves as a human-readable identifier, making it easier to track, compare, and analyze different runs.
#
# ##### The Importance of Naming Runs:
#
# - **Reference by Name**: While MLflow provides unique identifying keys like `run_id` for each run, having a descriptive name allows for more intuitive referencing, especially when using particular APIs and navigating the MLflow UI.
#
# - **Clarity and Context**: A well-chosen run name can provide context about the hypothesis being tested or the specific modifications made, aiding in understanding the purpose and rationale of a particular run.
#
# - **Automatic Naming**: If you don't specify a run name, MLflow will generate a unique fun name for you. However, this might lack the context and clarity of a manually chosen name.
#
# ##### Best Practices:
#
# When naming your runs, consider the following:
#
# 1. **Relevance to Code Changes**: The name should reflect any code or parameter modifications made for that run.
# 2. **Iterative Runs**: If you're executing multiple runs iteratively, it's a good idea to update the run name for each iteration to avoid confusion.
#
# In the subsequent steps, we will set a name for our parent run. Remember, if you execute the model training multiple times, consider updating the run name for clarity.

# %%
run_name = "first_attempt"

# %%
# Initiate the parent run and call the hyperparameter tuning child run logic
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name, nested=True):
    # Initialize the Optuna study
    study = optuna.create_study(direction="minimize")

    # Execute the hyperparameter optimization trials.
    # Note the addition of the `champion_callback` inclusion to control our logging
    study.optimize(objective, n_trials=500, callbacks=[champion_callback])

    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_mse", study.best_value)
    mlflow.log_metric("best_rmse", math.sqrt(study.best_value))

    # Log tags
    mlflow.set_tags(
        tags={
            "project": "Apple Demand Project",
            "optimizer_engine": "optuna",
            "model_family": "xgboost",
            "feature_set_version": 1,
        }
    )

    # Log a fit model instance
    model = xgb.train(study.best_params, dtrain)

    # Log the correlation plot
    mlflow.log_figure(figure=correlation_plot, artifact_file="correlation_plot.png")

    # Log the feature importances plot
    importances = plot_feature_importance(model, booster=study.best_params.get("booster"))
    mlflow.log_figure(figure=importances, artifact_file="feature_importances.png")

    # Log the residuals plot
    residuals = plot_residuals(model, dvalid, valid_y)
    mlflow.log_figure(figure=residuals, artifact_file="residuals.png")

    artifact_path = "model_artifacts"

    mlflow.xgboost.log_model(
        xgb_model=model,
        artifact_path=artifact_path,
        input_example=train_x.iloc[[0]],
        model_format="ubj",
        metadata={"model_data_version": 1},
    )

    # Get the logged model uri so that we can load it from the artifact store
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# 🏃 View run amusing-pig-759 at: http://localhost:5000/#/experiments/671527703213651607/runs/9e263562bcca4b488780338d9a902ee1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Initial trial 0 achieved value: 63072.58621753678
# 🏃 View run crawling-shoat-167 at: http://localhost:5000/#/experiments/671527703213651607/runs/53f6dae0f9474fc99d78ab805ef6d54d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 1 achieved value: 19408.667491090375 with  224.9712% improvement
# 🏃 View run clumsy-gnat-518 at: http://localhost:5000/#/experiments/671527703213651607/runs/0b24b1f8f6dd48f484d9df144a43665a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run overjoyed-sloth-343 at: http://localhost:5000/#/experiments/671527703213651607/runs/d692dd4eed8e4bd4a87c4d5d560a0802
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 3 achieved value: 19408.486303678714 with  0.0009% improvement
# 🏃 View run upbeat-wolf-678 at: http://localhost:5000/#/experiments/671527703213651607/runs/1b65c5bb44d64dd8880e67cb461b8c9a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run omniscient-zebra-298 at: http://localhost:5000/#/experiments/671527703213651607/runs/3c110b74a2af4fc79779f634a1f64edd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run tasteful-mare-16 at: http://localhost:5000/#/experiments/671527703213651607/runs/66cb5d7e93b24a2d8b1e75b4415d086d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 6 achieved value: 15462.009153463712 with  25.5237% improvement
# 🏃 View run unleashed-tern-790 at: http://localhost:5000/#/experiments/671527703213651607/runs/d096c0ab36aa4980997eba71f9c1b45b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run defiant-lamb-745 at: http://localhost:5000/#/experiments/671527703213651607/runs/29f657aa3c954856a2fb06059e709c96
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-vole-643 at: http://localhost:5000/#/experiments/671527703213651607/runs/46c2859b78e0421f9bd89122aad97c98
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run kindly-auk-274 at: http://localhost:5000/#/experiments/671527703213651607/runs/575fa9f813614f9389f7e98165aa7af6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run indecisive-toad-118 at: http://localhost:5000/#/experiments/671527703213651607/runs/33f0e12efb104c2cb2095eee3acd45fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run chill-donkey-121 at: http://localhost:5000/#/experiments/671527703213651607/runs/0a2793cd287b4101be50f8f94e9d1a99
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delightful-goose-706 at: http://localhost:5000/#/experiments/671527703213651607/runs/8f9ecffef9224bce978d7e4ac5cfb440
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-grub-588 at: http://localhost:5000/#/experiments/671527703213651607/runs/d15654699b67452389587b8f96afad14
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delightful-cod-848 at: http://localhost:5000/#/experiments/671527703213651607/runs/c00bb12222af432f8c87d52b63fb4adb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run defiant-crow-81 at: http://localhost:5000/#/experiments/671527703213651607/runs/bbe57521f5b94bff9b989dbb8e3e8f03
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unleashed-wren-440 at: http://localhost:5000/#/experiments/671527703213651607/runs/63c495d077704c86a32b547405629475
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run resilient-gnu-101 at: http://localhost:5000/#/experiments/671527703213651607/runs/2cecdf2ead9747789a36d3c5a1c009dc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mysterious-chimp-170 at: http://localhost:5000/#/experiments/671527703213651607/runs/295462f3b9a44572822477c44624049a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run zealous-toad-18 at: http://localhost:5000/#/experiments/671527703213651607/runs/4ca0ed2ba0e64411b4fa3c14e356de97
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run zealous-hound-24 at: http://localhost:5000/#/experiments/671527703213651607/runs/12ee453646f2470babea378e74ea7b24
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-snake-963 at: http://localhost:5000/#/experiments/671527703213651607/runs/8bb8385ffe7143229fa45d81e7447f5b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fearless-ram-808 at: http://localhost:5000/#/experiments/671527703213651607/runs/5fd237c325904d8b853438f772b314d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run inquisitive-lynx-436 at: http://localhost:5000/#/experiments/671527703213651607/runs/8a18feb3a7fe42c08554d500debc5e8b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delicate-crab-879 at: http://localhost:5000/#/experiments/671527703213651607/runs/9500901915f64afb9782340ba55cdbeb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run crawling-sow-147 at: http://localhost:5000/#/experiments/671527703213651607/runs/4778feffaed34fd196f8e90cde0bb9cb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sassy-sow-166 at: http://localhost:5000/#/experiments/671527703213651607/runs/3ba2657a0a32480c8dccaba4424668fa
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upset-steed-545 at: http://localhost:5000/#/experiments/671527703213651607/runs/0221f82755584ac18e184ff1f0fda623
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run blushing-mouse-385 at: http://localhost:5000/#/experiments/671527703213651607/runs/2dd9033a8df541f0b6bdb4a17fdfc35a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thundering-shark-362 at: http://localhost:5000/#/experiments/671527703213651607/runs/c06672fe654d444a84c5ebce1e203e13
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thoughtful-fox-270 at: http://localhost:5000/#/experiments/671527703213651607/runs/a708a378e99d4145ac0c2deff780cdae
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run tasteful-toad-852 at: http://localhost:5000/#/experiments/671527703213651607/runs/09de40bde84d42ed8bdd9618e88ca6dc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run luminous-stoat-16 at: http://localhost:5000/#/experiments/671527703213651607/runs/271e9f1a02f84b58830e71c32ea1ec93
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run spiffy-lynx-268 at: http://localhost:5000/#/experiments/671527703213651607/runs/567678e0f16949f0b27aec797cf76923
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nebulous-crab-507 at: http://localhost:5000/#/experiments/671527703213651607/runs/a75e0cfbd9d24cf590528cc4c880728b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-flea-420 at: http://localhost:5000/#/experiments/671527703213651607/runs/6c1bff0be8254d8e9dc60c69dcc4a9d0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thundering-gnu-994 at: http://localhost:5000/#/experiments/671527703213651607/runs/53afac93152d4219b0336eac78b0cbc1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run charming-pig-187 at: http://localhost:5000/#/experiments/671527703213651607/runs/a0d6ff66d66847cca0f7b10d787791c3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bemused-tern-632 at: http://localhost:5000/#/experiments/671527703213651607/runs/6013baa1803c41248931d698bdfcfd33
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run calm-steed-9 at: http://localhost:5000/#/experiments/671527703213651607/runs/16c5ce17250d4902afc02a3b8acf1051
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run colorful-fly-169 at: http://localhost:5000/#/experiments/671527703213651607/runs/712dd809f5f54390942d3bf33773ba84
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run stylish-elk-84 at: http://localhost:5000/#/experiments/671527703213651607/runs/23883b26dec04331b167db190ba09298
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run serious-steed-124 at: http://localhost:5000/#/experiments/671527703213651607/runs/5cb42aa9b6984f919e9e49508bee2177
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upbeat-koi-574 at: http://localhost:5000/#/experiments/671527703213651607/runs/bac7eb72bc294ed8a0cc8558c205cfd4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run selective-ox-154 at: http://localhost:5000/#/experiments/671527703213651607/runs/35a61dfff79e4cc797b632eb2411f85a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run casual-lynx-451 at: http://localhost:5000/#/experiments/671527703213651607/runs/c46454e395444f8b84abafdea7816753
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enthused-bear-569 at: http://localhost:5000/#/experiments/671527703213651607/runs/7566f85ced7f49c295eb38aa4274fe11
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skillful-conch-841 at: http://localhost:5000/#/experiments/671527703213651607/runs/e0421aade0774ca79be38e0e247c4608
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rare-dog-718 at: http://localhost:5000/#/experiments/671527703213651607/runs/06c9fe94f9d04e89bfc9ffd23d6dba05
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sassy-sow-101 at: http://localhost:5000/#/experiments/671527703213651607/runs/ed4a2443b22446c08dbee4ec61985169
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run exultant-seal-922 at: http://localhost:5000/#/experiments/671527703213651607/runs/6b44bd64098f437997c2b05fe3218134
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unequaled-whale-425 at: http://localhost:5000/#/experiments/671527703213651607/runs/d0ce2bb7593d4adf9d7255fc1f90bff2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run handsome-mink-85 at: http://localhost:5000/#/experiments/671527703213651607/runs/92bd15880b67423ab25398c767775947
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run calm-shoat-518 at: http://localhost:5000/#/experiments/671527703213651607/runs/8a845c883bfe4b8e91e2e01a5b461027
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 54 achieved value: 15453.126531240683 with  0.0575% improvement
# 🏃 View run rogue-penguin-244 at: http://localhost:5000/#/experiments/671527703213651607/runs/6556950815ad4adc8acf1e38ac1a6e49
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-horse-822 at: http://localhost:5000/#/experiments/671527703213651607/runs/fc2cf6f53c444b29ad4e4b7ae0e19bb5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capricious-yak-357 at: http://localhost:5000/#/experiments/671527703213651607/runs/32ae651512f241f8bf90271ab6aa2855
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run vaunted-pug-38 at: http://localhost:5000/#/experiments/671527703213651607/runs/3000dbf7748e43d5a43899708199ba09
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run kindly-deer-204 at: http://localhost:5000/#/experiments/671527703213651607/runs/ea6b140d323f46969ca8dcb8b00ea39b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 59 achieved value: 15441.309000961894 with  0.0765% improvement
# 🏃 View run loud-loon-931 at: http://localhost:5000/#/experiments/671527703213651607/runs/c010f602107c46cda36233e6df95f162
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run stylish-chimp-758 at: http://localhost:5000/#/experiments/671527703213651607/runs/1d7f1082aba74fd9b203aca020302269
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run big-ant-904 at: http://localhost:5000/#/experiments/671527703213651607/runs/c19bbaba135a47e688d31cff65c68e73
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run big-snipe-832 at: http://localhost:5000/#/experiments/671527703213651607/runs/0366cb3b9b2f49b9b15c5b16c5c04455
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run placid-sponge-122 at: http://localhost:5000/#/experiments/671527703213651607/runs/081d659d16b0480f94d323dad50165fe
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run trusting-pig-603 at: http://localhost:5000/#/experiments/671527703213651607/runs/b5f67751d9eb42889019e74e286342f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run charming-sheep-488 at: http://localhost:5000/#/experiments/671527703213651607/runs/6adac3bd900341eb941d7233bd44bed2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run classy-swan-642 at: http://localhost:5000/#/experiments/671527703213651607/runs/38908373cb414201ae90881e859224ef
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run monumental-perch-797 at: http://localhost:5000/#/experiments/671527703213651607/runs/e0fb883043b745afa82d7578c2986100
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run selective-dog-535 at: http://localhost:5000/#/experiments/671527703213651607/runs/0599dbe5edc449eeb3a3e1adc5bff9d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-calf-918 at: http://localhost:5000/#/experiments/671527703213651607/runs/3db4ed76257a47f5922516e2751cfbf1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run luminous-foal-703 at: http://localhost:5000/#/experiments/671527703213651607/runs/c8ffde8b4e684eecb5cdf7b2e2975645
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-cod-18 at: http://localhost:5000/#/experiments/671527703213651607/runs/be2264c390ab4cf9abf1bb8bb115edd0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run big-shrew-853 at: http://localhost:5000/#/experiments/671527703213651607/runs/83828b90ab4147d58bc92e2418002b62
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dashing-dog-371 at: http://localhost:5000/#/experiments/671527703213651607/runs/00cdd116f74e49e7b66bb64c9b7ac238
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run selective-yak-514 at: http://localhost:5000/#/experiments/671527703213651607/runs/b92d1d138240401e8225f6936bcdefc0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rare-grub-630 at: http://localhost:5000/#/experiments/671527703213651607/runs/6cf23e3703d743a79793ad3cf4dc060f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run welcoming-lynx-653 at: http://localhost:5000/#/experiments/671527703213651607/runs/04f3aff5a55148109dcb0fa570c5915c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run grandiose-crow-313 at: http://localhost:5000/#/experiments/671527703213651607/runs/2d1fe14105594887bcd6b6d4948a4076
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capricious-sheep-840 at: http://localhost:5000/#/experiments/671527703213651607/runs/e106c3b5e24045b9b3f4bb5033b95030
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nosy-zebra-26 at: http://localhost:5000/#/experiments/671527703213651607/runs/dd6b7678e3284a6594e5d5916dde654c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run glamorous-whale-386 at: http://localhost:5000/#/experiments/671527703213651607/runs/a2f3299522e64d01a529649df3ac0c0a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 81 achieved value: 15329.324952798497 with  0.7305% improvement
# 🏃 View run auspicious-snake-521 at: http://localhost:5000/#/experiments/671527703213651607/runs/bd72ecbebdf5466a950987cb5ffb1471
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run aged-duck-865 at: http://localhost:5000/#/experiments/671527703213651607/runs/6701f60a2cb84a63b02cd3b0d3ffa567
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capable-koi-28 at: http://localhost:5000/#/experiments/671527703213651607/runs/aafc0f45631a475ea7e976736bc9093d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run carefree-jay-341 at: http://localhost:5000/#/experiments/671527703213651607/runs/1e02925df8394108b2db06e994b63a08
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run receptive-moth-528 at: http://localhost:5000/#/experiments/671527703213651607/runs/c2cc6d6d203d40fbaded9531dc9283ce
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run victorious-bug-50 at: http://localhost:5000/#/experiments/671527703213651607/runs/04a302e36e1045c892b5d3e137748f0b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run popular-fly-534 at: http://localhost:5000/#/experiments/671527703213651607/runs/d345ce457b5d4baa9156c741d1058c07
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run spiffy-wolf-297 at: http://localhost:5000/#/experiments/671527703213651607/runs/f50cfdb2c3ec4efd857cea55b51dc774
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run masked-ray-185 at: http://localhost:5000/#/experiments/671527703213651607/runs/f071f65c43574d3b9db60f00fc2f6a28
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run serious-owl-627 at: http://localhost:5000/#/experiments/671527703213651607/runs/369809d562df476abc1ac1e32ea3e99e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run big-gnu-133 at: http://localhost:5000/#/experiments/671527703213651607/runs/d501c89027e84cfa9a4c4ba8a9ec070a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run overjoyed-shad-463 at: http://localhost:5000/#/experiments/671527703213651607/runs/8ca338c6110a42be8a395975dfebd255
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run invincible-stag-93 at: http://localhost:5000/#/experiments/671527703213651607/runs/2e1d75ed3e7e443faf3b9d992654bb55
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-skunk-483 at: http://localhost:5000/#/experiments/671527703213651607/runs/4dfde93de3bf4901b2bc300a8841b3fc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 95 achieved value: 15283.69036245475 with  0.2986% improvement
# 🏃 View run delightful-goat-619 at: http://localhost:5000/#/experiments/671527703213651607/runs/f24d66452dba41139f5dab13334c5331
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run big-bird-167 at: http://localhost:5000/#/experiments/671527703213651607/runs/f208a5ac79574b8cac09b54660dd8b03
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run magnificent-doe-228 at: http://localhost:5000/#/experiments/671527703213651607/runs/dfb65938bdfc4b5ba13e1cc381f1c257
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sneaky-sow-559 at: http://localhost:5000/#/experiments/671527703213651607/runs/ab330583e3bf40ba850e8098db08b4c9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run kindly-shrike-942 at: http://localhost:5000/#/experiments/671527703213651607/runs/ccf18390229643c3a54ff7c394049931
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run smiling-sow-475 at: http://localhost:5000/#/experiments/671527703213651607/runs/18671effbfc749539a9458193130d06f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-ray-965 at: http://localhost:5000/#/experiments/671527703213651607/runs/fea770c5a5f74e688c0c1c09e0fd4c65
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mysterious-bear-399 at: http://localhost:5000/#/experiments/671527703213651607/runs/9c50d4cfd37f40dd817bfce094716e47
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run monumental-tern-595 at: http://localhost:5000/#/experiments/671527703213651607/runs/e9de10081a1e44a19be33dd12acbd69a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run glamorous-cow-983 at: http://localhost:5000/#/experiments/671527703213651607/runs/0c4fa2751c42460ba970daec22b486e0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run persistent-fish-975 at: http://localhost:5000/#/experiments/671527703213651607/runs/f92d6714fb334967bee5b68bf4c0018b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run suave-cub-592 at: http://localhost:5000/#/experiments/671527703213651607/runs/01535afcae4e465eb51d6238dcd3dff9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run powerful-wasp-803 at: http://localhost:5000/#/experiments/671527703213651607/runs/fafadb570cd34ccaa1cfc19c29d82d27
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run awesome-sloth-534 at: http://localhost:5000/#/experiments/671527703213651607/runs/51b8c36e63b1498f95b4c45b33f628a4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run burly-tern-116 at: http://localhost:5000/#/experiments/671527703213651607/runs/169e13d4109d445aac94b4a959443c4c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run persistent-asp-745 at: http://localhost:5000/#/experiments/671527703213651607/runs/6b27051b96c041798a76436b2017e587
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adaptable-yak-917 at: http://localhost:5000/#/experiments/671527703213651607/runs/885d2936e38b47bfbc0fea86c950357a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 112 achieved value: 15123.536892018712 with  1.0590% improvement
# 🏃 View run enchanting-asp-584 at: http://localhost:5000/#/experiments/671527703213651607/runs/27e73e5f3ed04f5585f1cc11b24221e4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run selective-jay-789 at: http://localhost:5000/#/experiments/671527703213651607/runs/14731e3e96194236afcc7719518373be
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run invincible-perch-76 at: http://localhost:5000/#/experiments/671527703213651607/runs/801805b3144142e2bfb0edebe3cb39c9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run victorious-worm-402 at: http://localhost:5000/#/experiments/671527703213651607/runs/2d6717c68bcf422db20bf38d7bcce203
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mysterious-wren-147 at: http://localhost:5000/#/experiments/671527703213651607/runs/0636797280334d30a26c233a22bc8425
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run judicious-grouse-441 at: http://localhost:5000/#/experiments/671527703213651607/runs/3c8d31b7e2d340e4b9ca277a7df84282
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run resilient-pig-535 at: http://localhost:5000/#/experiments/671527703213651607/runs/1eb1ff236e194898b61bcda2f1319ee6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sedate-crow-399 at: http://localhost:5000/#/experiments/671527703213651607/runs/ce8accf45ec74fda9a62aaca6259d3c4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enchanting-foal-632 at: http://localhost:5000/#/experiments/671527703213651607/runs/a045d8ed55f449529affea34fadafdc6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enchanting-steed-165 at: http://localhost:5000/#/experiments/671527703213651607/runs/55e32e8bc99f4d6da828b92b4dd31509
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nebulous-snipe-6 at: http://localhost:5000/#/experiments/671527703213651607/runs/807f23749103401483ef5347d5c92ced
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upbeat-swan-22 at: http://localhost:5000/#/experiments/671527703213651607/runs/b45edbb0635b403eb4a6d8dd5df5cc48
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run overjoyed-mare-193 at: http://localhost:5000/#/experiments/671527703213651607/runs/93fe291831204429bdcd2400d87d4c56
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mysterious-fly-579 at: http://localhost:5000/#/experiments/671527703213651607/runs/a3db1edf0dec45029ad4f63743f55b2b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run lyrical-shad-642 at: http://localhost:5000/#/experiments/671527703213651607/runs/cbf55a023d1a46a8b68c84823a60c426
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bustling-shoat-633 at: http://localhost:5000/#/experiments/671527703213651607/runs/7d4226b3fb96432fa6a080ef84db7ab4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run charming-boar-838 at: http://localhost:5000/#/experiments/671527703213651607/runs/7896f03c9735404d9b4f72995daa74fc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run carefree-cub-44 at: http://localhost:5000/#/experiments/671527703213651607/runs/bc5e778734194970b699d7dfd38770ec
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run merciful-midge-305 at: http://localhost:5000/#/experiments/671527703213651607/runs/d14ccda7dde24233983019ad76170adc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run burly-steed-339 at: http://localhost:5000/#/experiments/671527703213651607/runs/5fb806dbd6fe41cc8109be9ada7e4019
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run efficient-cub-732 at: http://localhost:5000/#/experiments/671527703213651607/runs/84fda21278b84636a6c376a721f5d098
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run whimsical-whale-305 at: http://localhost:5000/#/experiments/671527703213651607/runs/4acc421d8dba418ba40e2966b1c8bc45
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bright-grouse-259 at: http://localhost:5000/#/experiments/671527703213651607/runs/8509e75738bd476b9dee3a9db5e5daa1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run victorious-shrimp-95 at: http://localhost:5000/#/experiments/671527703213651607/runs/80d16d34f4064178a53e6cbc1d865a75
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run learned-wolf-406 at: http://localhost:5000/#/experiments/671527703213651607/runs/97644adf311244de8e6780bd9137b898
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run merciful-donkey-108 at: http://localhost:5000/#/experiments/671527703213651607/runs/a279a46d629d498a9c925ce40e58ba6a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run youthful-wasp-996 at: http://localhost:5000/#/experiments/671527703213651607/runs/7080e299678a459ca7867c58ca749a8a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sneaky-frog-469 at: http://localhost:5000/#/experiments/671527703213651607/runs/0677c96cfa8443cfb53c779c7029d6f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delightful-smelt-70 at: http://localhost:5000/#/experiments/671527703213651607/runs/98bd827749cd4d4385edc6cc72a35b36
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capricious-hawk-613 at: http://localhost:5000/#/experiments/671527703213651607/runs/df2b17fd03064e6c994a1ef56bf3f474
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-loon-497 at: http://localhost:5000/#/experiments/671527703213651607/runs/4ffe42e1e1d241cb830868bc0f36a9ef
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run masked-hen-532 at: http://localhost:5000/#/experiments/671527703213651607/runs/671740cf473c4d718ceada32b0a903d2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clean-lark-580 at: http://localhost:5000/#/experiments/671527703213651607/runs/2eaeb85650414274908a83c151336222
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run zealous-panda-427 at: http://localhost:5000/#/experiments/671527703213651607/runs/27c689d9672a4731807daa7cbe32b8ee
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run classy-lamb-173 at: http://localhost:5000/#/experiments/671527703213651607/runs/85b4e6cf17404bcb8b3ea97a583d3b4e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-dog-909 at: http://localhost:5000/#/experiments/671527703213651607/runs/269ce005da8243059d2cd6a11b4a0905
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run luminous-donkey-255 at: http://localhost:5000/#/experiments/671527703213651607/runs/d1692ac6e48842b88dd4ac1c4a2ba9b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adaptable-wasp-528 at: http://localhost:5000/#/experiments/671527703213651607/runs/62906f0947b747428191bd21490e67d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abundant-steed-947 at: http://localhost:5000/#/experiments/671527703213651607/runs/0b3a8a53b8db4200814149fce7f9ddb8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-wren-653 at: http://localhost:5000/#/experiments/671527703213651607/runs/ea14aa1034324414a5cb142ed7362641
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adaptable-cod-116 at: http://localhost:5000/#/experiments/671527703213651607/runs/22d503d880e44f90bc817883f993f589
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rumbling-fawn-509 at: http://localhost:5000/#/experiments/671527703213651607/runs/4fefbd411dd24765b1e144404723ad94
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run invincible-skink-18 at: http://localhost:5000/#/experiments/671527703213651607/runs/4b4afa54e31e4a319e213eabf8e233a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run chill-stoat-507 at: http://localhost:5000/#/experiments/671527703213651607/runs/07c502e6dadd481c9e5197b727218c6d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-frog-974 at: http://localhost:5000/#/experiments/671527703213651607/runs/bf1e20559610415ca8568f37f77d62a8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enthused-hog-363 at: http://localhost:5000/#/experiments/671527703213651607/runs/7395c78b07b946c4a003b3c9e7086dae
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run chill-fish-567 at: http://localhost:5000/#/experiments/671527703213651607/runs/a0b63ae5e7e9498b99b31ca86a231c75
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run incongruous-yak-827 at: http://localhost:5000/#/experiments/671527703213651607/runs/85c846d9361d4924bfe7f7a9188ae3c0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nosy-yak-779 at: http://localhost:5000/#/experiments/671527703213651607/runs/1dae4183b5524b07a5c8c0cd57a22c3a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abundant-skink-230 at: http://localhost:5000/#/experiments/671527703213651607/runs/247c5323c0804e008d0657a68dffb2aa
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-squid-606 at: http://localhost:5000/#/experiments/671527703213651607/runs/4f3b53d1b264484caf5e8e33bf9f5fba
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run aged-crane-197 at: http://localhost:5000/#/experiments/671527703213651607/runs/a3e3c8a1b4eb40d0840469658b4a7d09
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run suave-snail-701 at: http://localhost:5000/#/experiments/671527703213651607/runs/f398eb82e870463e8f9272a12ec6b3b8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run kindly-midge-268 at: http://localhost:5000/#/experiments/671527703213651607/runs/974e754ed78b4968ab575196fb12019a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adaptable-stag-260 at: http://localhost:5000/#/experiments/671527703213651607/runs/e42df69441fe49fdaf3dc9d168d2b057
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run crawling-deer-147 at: http://localhost:5000/#/experiments/671527703213651607/runs/7b7654de305e4727a661f1976b1ca9d4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run exultant-stag-657 at: http://localhost:5000/#/experiments/671527703213651607/runs/19e94d5f1a054b9691e77751eaa85a3c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run righteous-toad-516 at: http://localhost:5000/#/experiments/671527703213651607/runs/a87a5c3fae434b7b8d4a544c4f767703
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run silent-lamb-732 at: http://localhost:5000/#/experiments/671527703213651607/runs/ae46c17a6f29445b8936c364fdb2993b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unruly-quail-970 at: http://localhost:5000/#/experiments/671527703213651607/runs/d0468a494a5e4ece811e9e5fc9d57385
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run honorable-mole-877 at: http://localhost:5000/#/experiments/671527703213651607/runs/2c852daaa4ff4dfea88fe0a8f713ffa7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run silent-carp-648 at: http://localhost:5000/#/experiments/671527703213651607/runs/9116213f34aa4633aabcd394a194bf2e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run selective-cub-459 at: http://localhost:5000/#/experiments/671527703213651607/runs/ebf4a52c125b48e287e1c94d2d7413ca
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run hilarious-stork-910 at: http://localhost:5000/#/experiments/671527703213651607/runs/b1068c51b4184822be1ac49315cafed7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unleashed-roo-653 at: http://localhost:5000/#/experiments/671527703213651607/runs/63c50e83701e4e1e80c524ef27ea02bf
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run defiant-wolf-760 at: http://localhost:5000/#/experiments/671527703213651607/runs/b4cb66f0b2c84d9885225c270319fdc5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run lyrical-foal-684 at: http://localhost:5000/#/experiments/671527703213651607/runs/a0df629ba2e649e38164c618628694ed
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run zealous-hen-95 at: http://localhost:5000/#/experiments/671527703213651607/runs/eee6a0f3e210446a8f3bba06a058d385
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run awesome-gull-642 at: http://localhost:5000/#/experiments/671527703213651607/runs/3fbd7ac91262455b8e977fe4e077864c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run glamorous-hound-143 at: http://localhost:5000/#/experiments/671527703213651607/runs/8e37b1ee8e1f4184bf6e87f77c3fe719
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run spiffy-bat-994 at: http://localhost:5000/#/experiments/671527703213651607/runs/38f9c3520012404a9881db3134f9a5c9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run whimsical-shoat-171 at: http://localhost:5000/#/experiments/671527703213651607/runs/cd8f2fac981e41c181b2c682620024f9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run ambitious-steed-930 at: http://localhost:5000/#/experiments/671527703213651607/runs/4cbcfcf2abdf4e0a98dfb3744eddf704
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adventurous-yak-20 at: http://localhost:5000/#/experiments/671527703213651607/runs/1a341b6a68a34a818fb6c6cbdbf8a987
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abrasive-ray-703 at: http://localhost:5000/#/experiments/671527703213651607/runs/7aa535feb7b34740bb266a36521c6819
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mercurial-asp-488 at: http://localhost:5000/#/experiments/671527703213651607/runs/c24ef0e307a147c9ac1c8d8324c6a7f2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rebellious-loon-690 at: http://localhost:5000/#/experiments/671527703213651607/runs/ef388672fe9441e8bc4133c5ad25370f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nebulous-sloth-130 at: http://localhost:5000/#/experiments/671527703213651607/runs/90593a76ea9a491da1f9e9e96c32df15
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run intrigued-goose-668 at: http://localhost:5000/#/experiments/671527703213651607/runs/9b2edb4a06344513a84f0c92bd97a686
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wise-croc-343 at: http://localhost:5000/#/experiments/671527703213651607/runs/999e72652f274692b383103dfafc77f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run silent-goat-551 at: http://localhost:5000/#/experiments/671527703213651607/runs/1ebda87e6af14189808d27974749beeb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capricious-eel-109 at: http://localhost:5000/#/experiments/671527703213651607/runs/9bb553357e124a98ab90237affa10b31
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mercurial-pig-505 at: http://localhost:5000/#/experiments/671527703213651607/runs/41a9663cc6744120b47ced151ea2f713
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run defiant-vole-853 at: http://localhost:5000/#/experiments/671527703213651607/runs/f3e27d26c4dc4c7988158a0a77cc93c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run brawny-penguin-247 at: http://localhost:5000/#/experiments/671527703213651607/runs/d945f1fe54554aa9b387da8d530ba075
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adventurous-frog-389 at: http://localhost:5000/#/experiments/671527703213651607/runs/34ba2ae21a8e406b90ae1b1b288aa896
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run smiling-koi-621 at: http://localhost:5000/#/experiments/671527703213651607/runs/b7c034f6bc06445d96420ac414c14a0b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run kindly-steed-387 at: http://localhost:5000/#/experiments/671527703213651607/runs/c0769858085a451392cfd7aefac572a8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-slug-257 at: http://localhost:5000/#/experiments/671527703213651607/runs/ddb6984670e644168676c445a00be6a8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run carefree-bat-356 at: http://localhost:5000/#/experiments/671527703213651607/runs/e0331e8829124a8baf29f63f3361938f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rare-smelt-634 at: http://localhost:5000/#/experiments/671527703213651607/runs/8525ccaf727f4673b4514429aa205388
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run persistent-wren-84 at: http://localhost:5000/#/experiments/671527703213651607/runs/d792f766986b4ea981193c4373764147
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clean-skunk-202 at: http://localhost:5000/#/experiments/671527703213651607/runs/5663eb20c710493c9a2d94dbad1e0a53
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-fawn-77 at: http://localhost:5000/#/experiments/671527703213651607/runs/a265f55244e7406fad76e96a1659e3fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delicate-slug-868 at: http://localhost:5000/#/experiments/671527703213651607/runs/37155756311247d3b9cde2a1b29161d6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rumbling-midge-565 at: http://localhost:5000/#/experiments/671527703213651607/runs/2e51eb32d495488384f11ca8ef21cc26
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run judicious-fly-867 at: http://localhost:5000/#/experiments/671527703213651607/runs/7335171500214f58887b836e024cb05f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sassy-ram-180 at: http://localhost:5000/#/experiments/671527703213651607/runs/dd762580223141a4801b454ce795e53b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run resilient-hound-919 at: http://localhost:5000/#/experiments/671527703213651607/runs/a3a20186a5014eefa74d6b2f076ca4b7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run lyrical-smelt-640 at: http://localhost:5000/#/experiments/671527703213651607/runs/90064b77de4b49fbba07ffac4471e95d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-mole-162 at: http://localhost:5000/#/experiments/671527703213651607/runs/1deecf0ba9404246b0fdfb2ab5c31211
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run useful-duck-795 at: http://localhost:5000/#/experiments/671527703213651607/runs/34cc3aa737474fd698b2256037868445
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amusing-sheep-316 at: http://localhost:5000/#/experiments/671527703213651607/runs/6d827a2da6db4ca9973445744ebbdc02
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run traveling-snail-151 at: http://localhost:5000/#/experiments/671527703213651607/runs/44aab6adaaf14ac0bbe2a61372275f6c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capable-lynx-478 at: http://localhost:5000/#/experiments/671527703213651607/runs/a6a93b66add546a9a585c2a88b24ee54
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nervous-yak-193 at: http://localhost:5000/#/experiments/671527703213651607/runs/6398fe3b60664cf59a8cf3fb2845d42d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rare-smelt-821 at: http://localhost:5000/#/experiments/671527703213651607/runs/3776c33ea354471a878d0425095e2a0a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run salty-yak-709 at: http://localhost:5000/#/experiments/671527703213651607/runs/2dbef46e8229474eac83cee7be2502c2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-shrike-231 at: http://localhost:5000/#/experiments/671527703213651607/runs/fed731cf41c1413b924d314e835c8ca1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run respected-newt-94 at: http://localhost:5000/#/experiments/671527703213651607/runs/24d0d1b4d820408b9d95abfc391d45eb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run hilarious-crow-446 at: http://localhost:5000/#/experiments/671527703213651607/runs/57526642c694432fb7fdf6c66ff21cb1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run exultant-dolphin-110 at: http://localhost:5000/#/experiments/671527703213651607/runs/837de979da284704896e6f8fa643b6ff
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run resilient-crab-429 at: http://localhost:5000/#/experiments/671527703213651607/runs/d71026ac477f4626911591868c31d6ce
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enthused-shrew-58 at: http://localhost:5000/#/experiments/671527703213651607/runs/67b654edff584e54be7e391621a27f80
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run learned-bee-617 at: http://localhost:5000/#/experiments/671527703213651607/runs/a9dd39c70219409f8654669312621884
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run spiffy-yak-345 at: http://localhost:5000/#/experiments/671527703213651607/runs/fb8783eba962424f89f26770ff9d6032
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run masked-flea-572 at: http://localhost:5000/#/experiments/671527703213651607/runs/07f92512507e4123b32c576c4677f489
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run luxuriant-fowl-843 at: http://localhost:5000/#/experiments/671527703213651607/runs/a82da591478f419ab028a66308b89fca
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run honorable-sow-466 at: http://localhost:5000/#/experiments/671527703213651607/runs/76e4b6dcc5894120a1958660174c70a6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-stoat-922 at: http://localhost:5000/#/experiments/671527703213651607/runs/d69e8c5846574546aa9411cf76fadd84
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run lyrical-shrike-747 at: http://localhost:5000/#/experiments/671527703213651607/runs/9e03606284104d13be5d54724d7d3910
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# ...
# 🏃 View run casual-vole-906 at: http://localhost:5000/#/experiments/671527703213651607/runs/93bdfedb84a24af29f2b38bef5e88099
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run omniscient-slug-723 at: http://localhost:5000/#/experiments/671527703213651607/runs/6779f95e27cd48b3a2bf2f431399e10c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skillful-shoat-949 at: http://localhost:5000/#/experiments/671527703213651607/runs/e4aadc55b24d4574ac50bd7f8d4a7041
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run melodic-bass-574 at: http://localhost:5000/#/experiments/671527703213651607/runs/a3b3059ad1024acbb45598b7e097a8bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nosy-mink-426 at: http://localhost:5000/#/experiments/671527703213651607/runs/31138d44dc2d496bace5145cd873da97
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wise-frog-857 at: http://localhost:5000/#/experiments/671527703213651607/runs/190cc5f20e334d8498facb2f73165a8b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dashing-yak-620 at: http://localhost:5000/#/experiments/671527703213651607/runs/ae3ade281cb04554ac664048aab03a39
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run persistent-dove-962 at: http://localhost:5000/#/experiments/671527703213651607/runs/f102e0bd79ae4578a938ba2c06ffacc9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run learned-tern-143 at: http://localhost:5000/#/experiments/671527703213651607/runs/5da477a298c94aaab350f496d7d7f0bc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bedecked-koi-210 at: http://localhost:5000/#/experiments/671527703213651607/runs/d62f17d5860846c0a35f1963b50c2bad
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sassy-koi-253 at: http://localhost:5000/#/experiments/671527703213651607/runs/d5f68cb3697b401e8912c7de823ba1f6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run colorful-shark-281 at: http://localhost:5000/#/experiments/671527703213651607/runs/86642ca49fab47d7b2c5757b84aa33f3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-jay-515 at: http://localhost:5000/#/experiments/671527703213651607/runs/13bcdd761bba453d92785208845b7271
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run caring-loon-23 at: http://localhost:5000/#/experiments/671527703213651607/runs/793bff790c764abd88b86f6d72f82c2e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delicate-yak-846 at: http://localhost:5000/#/experiments/671527703213651607/runs/0c458a5c479b4213acbc61beba371766
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capricious-shrew-892 at: http://localhost:5000/#/experiments/671527703213651607/runs/5755c44917d04798a61e6bd37d2103df
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run stylish-carp-49 at: http://localhost:5000/#/experiments/671527703213651607/runs/bad35d3b12c5462dab8f86c36da686eb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run carefree-pug-393 at: http://localhost:5000/#/experiments/671527703213651607/runs/ba4b6b55e0444c8d86a977150f13546f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run legendary-pig-203 at: http://localhost:5000/#/experiments/671527703213651607/runs/614b6c7cbda943bfbf00b8d5a143549d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run likeable-hound-901 at: http://localhost:5000/#/experiments/671527703213651607/runs/5b91a9ade7ec4a069cc082ee2f5dfa54
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run serious-vole-850 at: http://localhost:5000/#/experiments/671527703213651607/runs/ffc1713b02eb45d08e2eb7f5b148b13f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run exultant-colt-547 at: http://localhost:5000/#/experiments/671527703213651607/runs/8d3227895b034e6eb9d4d8bb8c06ed47
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-stork-433 at: http://localhost:5000/#/experiments/671527703213651607/runs/bc71743e16574da8be0578f1fa5aece1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adventurous-boar-736 at: http://localhost:5000/#/experiments/671527703213651607/runs/a1c2694fdc894f7dbc92b82e335bec5c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run able-wren-658 at: http://localhost:5000/#/experiments/671527703213651607/runs/8a76e763d5aa4286bb608c20e97e2af4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run masked-swan-594 at: http://localhost:5000/#/experiments/671527703213651607/runs/86ed11b68b06485a862e374a9a46dbd8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run welcoming-lark-930 at: http://localhost:5000/#/experiments/671527703213651607/runs/535babf155b64346a537a9e4ff79b486
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run caring-shad-299 at: http://localhost:5000/#/experiments/671527703213651607/runs/3c9387ef513d42b1829056d4bb50aba3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run carefree-squid-622 at: http://localhost:5000/#/experiments/671527703213651607/runs/9f37f5a0e3ca482d9a1689a6b03a15d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bald-hog-841 at: http://localhost:5000/#/experiments/671527703213651607/runs/b6a37212611640efa9ffc5ff6cbc6514
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run painted-frog-304 at: http://localhost:5000/#/experiments/671527703213651607/runs/3beb8ea25c4442c1801ee9d5a14a60cb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run luminous-ram-171 at: http://localhost:5000/#/experiments/671527703213651607/runs/0b0e294bb990465ba2a5105f9332509d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run shivering-dove-607 at: http://localhost:5000/#/experiments/671527703213651607/runs/4a4860bb29de448c86607144f84061d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run handsome-carp-899 at: http://localhost:5000/#/experiments/671527703213651607/runs/e1d79568043b45859b979cff29301145
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run efficient-perch-622 at: http://localhost:5000/#/experiments/671527703213651607/runs/61f2d4363d004dcfa0374522a12b0cfd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enthused-hare-655 at: http://localhost:5000/#/experiments/671527703213651607/runs/f93e821d38804007a0b071c867832c71
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run powerful-swan-726 at: http://localhost:5000/#/experiments/671527703213651607/runs/c1d0e3b6899c48f7b74026b27cbf445e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run receptive-pig-805 at: http://localhost:5000/#/experiments/671527703213651607/runs/4b3aa03367964ab4a46616efcab82b10
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-mare-803 at: http://localhost:5000/#/experiments/671527703213651607/runs/b8be9f2cee41459e9b7cb26592db8a8a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upset-hare-834 at: http://localhost:5000/#/experiments/671527703213651607/runs/01e75b8971ff4ee2a3652d9ed9f86086
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unleashed-bat-823 at: http://localhost:5000/#/experiments/671527703213651607/runs/58ee298d8ca54cc0992ee9f68adb5a33
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adaptable-fawn-783 at: http://localhost:5000/#/experiments/671527703213651607/runs/9fb552fc13f3445c922d95aafcf6b18b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skittish-fly-163 at: http://localhost:5000/#/experiments/671527703213651607/runs/54ae2ec0b90a4fb489fa28e7c0f1cbe9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run honorable-duck-846 at: http://localhost:5000/#/experiments/671527703213651607/runs/d48694342ce946ebae1e5f500ab086d4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thoughtful-fly-963 at: http://localhost:5000/#/experiments/671527703213651607/runs/1388c63ffe3e48ceaad6037e73299c17
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run persistent-lark-668 at: http://localhost:5000/#/experiments/671527703213651607/runs/a3a8cfc8fde84222ac696c0be39046f3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run treasured-sloth-403 at: http://localhost:5000/#/experiments/671527703213651607/runs/9146ca0755ee432a87800c1dcf7d9a73
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wise-slug-736 at: http://localhost:5000/#/experiments/671527703213651607/runs/ece727651db34403872a9352937ba922
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run treasured-swan-884 at: http://localhost:5000/#/experiments/671527703213651607/runs/9aee2f6466854258a7e12f627a178d76
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rare-ape-901 at: http://localhost:5000/#/experiments/671527703213651607/runs/4f25333431754164b5bf7aa61f2eea58
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wise-doe-733 at: http://localhost:5000/#/experiments/671527703213651607/runs/1738af745d1f4166990e8388cd8b7dec
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nebulous-hen-362 at: http://localhost:5000/#/experiments/671527703213651607/runs/92d2c92d4c984620a191e093a3beb69a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run merciful-horse-13 at: http://localhost:5000/#/experiments/671527703213651607/runs/1be2d1655d4a4e3b81acce1a2d88fe9b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run illustrious-shad-405 at: http://localhost:5000/#/experiments/671527703213651607/runs/84788db371e84db096cf14618d68611f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run gaudy-goose-996 at: http://localhost:5000/#/experiments/671527703213651607/runs/cab3ab47ef98425689cf38d89b19e64b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run melodic-pug-660 at: http://localhost:5000/#/experiments/671527703213651607/runs/c47bc62c82f84005b4427036510941a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delicate-doe-842 at: http://localhost:5000/#/experiments/671527703213651607/runs/03a6719253c64cedad1c8d28855f1a43
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run traveling-ray-52 at: http://localhost:5000/#/experiments/671527703213651607/runs/5638654faef54993960ecbdf132f5066
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run gifted-sow-396 at: http://localhost:5000/#/experiments/671527703213651607/runs/0dcbf87a90c64349babc75ebd8789d48
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fortunate-robin-986 at: http://localhost:5000/#/experiments/671527703213651607/runs/c3787ff1413d4fb5bade7ec6975fd81f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run defiant-pig-354 at: http://localhost:5000/#/experiments/671527703213651607/runs/2a30d2cb02e34fbf8d0ccdfb601a2de9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run valuable-stork-461 at: http://localhost:5000/#/experiments/671527703213651607/runs/ba9a369b2bae43868a2192db33ef275d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run ambitious-snail-860 at: http://localhost:5000/#/experiments/671527703213651607/runs/e1c755f7779b487e81ec55fa90d12013
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run tasteful-conch-956 at: http://localhost:5000/#/experiments/671527703213651607/runs/3f8f6b3b39fb4eafbecd92964b1cfd71
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run tasteful-skunk-22 at: http://localhost:5000/#/experiments/671527703213651607/runs/8fd37310a7424042a90adf7a851c44f3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-shoat-347 at: http://localhost:5000/#/experiments/671527703213651607/runs/fca4e0f5999444d7be71a5e2e3c89f27
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nebulous-shrew-487 at: http://localhost:5000/#/experiments/671527703213651607/runs/153c6419b08f4b5d880075f621d8d210
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dashing-turtle-516 at: http://localhost:5000/#/experiments/671527703213651607/runs/1096d03f7c57454ca565f60a2009247f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sneaky-cat-26 at: http://localhost:5000/#/experiments/671527703213651607/runs/abd39b8d684b42cc99693bdc9114d7f2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-penguin-506 at: http://localhost:5000/#/experiments/671527703213651607/runs/0e248f0957024f0f8be0cfc53ad1e247
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run victorious-shrew-21 at: http://localhost:5000/#/experiments/671527703213651607/runs/2ff5f473b91d4d91968bd9f9a16de439
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-roo-777 at: http://localhost:5000/#/experiments/671527703213651607/runs/a453e22e5d114cd1ba71a55317b48d14
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nervous-perch-296 at: http://localhost:5000/#/experiments/671527703213651607/runs/f8cb1d1e1a9b4a49b58864b5147f8f15
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run painted-worm-437 at: http://localhost:5000/#/experiments/671527703213651607/runs/3c646acd36244fa5bac8b2ea9db10c95
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# /opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run first_attempt at: http://localhost:5000/#/experiments/671527703213651607/runs/65805a8a75d04022839e60dbbf8b397e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607

# %% [markdown]
# #### Understanding the Artifact URI in MLflow
#
# The output 'mlflow-artifacts:/908436739760555869/c8d64ce51f754eb698a3c09239bcdcee/artifacts/model' represents a unique Uniform Resource Identifier (URI) for the trained model artifacts within MLflow. This URI is a crucial component of MLflow's architecture, and here's why:
#
# ##### Simplified Access to Model Artifacts
#
# The `model_uri` abstracts away the underlying storage details, providing a consistent and straightforward way to reference model artifacts, regardless of where they are stored. Whether your artifacts are on a local filesystem, in a cloud storage bucket, or on a network mount, the URI remains a consistent reference point.
#
# ##### Abstraction of Storage Details
#
# MLflow is designed to be storage-agnostic. This means that while you might switch the backend storage from, say, a local directory to an Amazon S3 bucket, the way you interact with MLflow remains consistent. The URI ensures that you don't need to know the specifics of the storage backend; you only need to reference the model's URI.
#
# ##### Associated Information and Metadata
#
# Beyond just the model files, the URI provides access to associated metadata, the model artifact, and other logged artifacts (files and images). This ensures that you have a comprehensive set of information about the model, aiding in reproducibility, analysis, and deployment.
#
# ##### In Summary
#
# The `model_uri` serves as a consistent, abstracted reference to your model and its associated data. It simplifies interactions with MLflow, ensuring that users don't need to worry about the specifics of underlying storage mechanisms and can focus on the machine learning workflow.

# %%
model_uri
# Out:
# 'mlflow-artifacts:/671527703213651607/65805a8a75d04022839e60dbbf8b397e/artifacts/model_artifacts'

# %% [markdown]
# #### Loading the Trained Model with MLflow
#
# With the line:
#
# ```python
# loaded = mlflow.xgboost.load_model(model_uri)
# ```
# we're leveraging MLflow's native model loader for XGBoost. Instead of using the generic pyfunc loader, which provides a universal Python function interface for models, we're using the XGBoost-specific loader.
#
# ##### Benefits of Native Loading:
#
# - **Fidelity**: Loading the model using the native loader ensures that you're working with the exact same model object as it was during training. This means all nuances, specifics, and intricacies of the original model are preserved.
#
# - **Functionality**: With the native model object in hand, you can utilize all of its inherent methods and properties. This allows for more flexibility, especially when you need advanced features or fine-grained control during inference.
#
# - **Performance**: Using the native model object might offer performance benefits, especially when performing batch inference or deploying the model in environments optimized for the specific machine learning framework.
#
# In essence, by loading the model natively, we ensure maximum compatibility and functionality, allowing for a seamless transition from training to inference.

# %%
loaded = mlflow.xgboost.load_model(model_uri)
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# #### Example: Batch Inference Using the Loaded Model
#
# After loading the model natively, performing batch inference is straightforward.
#
# In the following cell, we're going to perform a prediction based on the entire source feature set.
# Although doing an inference action on the entire training and validation dataset features is of very limited utility in a real-world application, we'll use our generated synthetic data here to illustrate using the native model for inference.

# %% [markdown]
# #### Performing Batch Inference and Augmenting Data
#
# In this section, we're taking our entire dataset and performing batch inference using our loaded XGBoost model. We'll then append these predictions back into our original dataset to compare, analyze, or further process.
#
# ##### Steps Explained:
#
# 1. **Creating a DMatrix**: `batch_dmatrix = xgb.DMatrix(X)`: We first convert our features (`X`) into XGBoost's optimized DMatrix format. This data structure is specifically designed for efficiency and speed in XGBoost.
#
# 2. **Predictions**: `inference = loaded.predict(batch_dmatrix)`: Using the previously loaded model (`loaded`), we perform batch inference on the entire dataset.
#
# 3. **Creating a New DataFrame**: `infer_df = df.copy()`: We create a copy of the original DataFrame to ensure that we're not modifying our original data.
#
# 4. **Appending Predictions**: `infer_df["predicted_demand"] = inference`: The predictions are then added as a new column, `predicted_demand`, to this DataFrame.
#
# ##### Best Practices:
#
# - **Always Copy Data**: When augmenting or modifying datasets, it's generally a good idea to work with a copy. This ensures that the original data remains unchanged, preserving data integrity.
#
# - **Batch Inference**: When predicting on large datasets, using batch inference (as opposed to individual predictions) can offer significant speed improvements.
#
# - **DMatrix Conversion**: While converting to DMatrix might seem like an extra step, it's crucial for performance when working with XGBoost. It ensures that predictions are made as quickly as possible.
#
# In the subsequent steps, we can further analyze the differences between the actual demand and our model's predicted demand, potentially visualizing the results or calculating performance metrics.

# %%
batch_dmatrix = xgb.DMatrix(X)

inference = loaded.predict(batch_dmatrix)

infer_df = df.copy()

infer_df["predicted_demand"] = inference

# %% [markdown]
# #### Visualizing the Augmented DataFrame
#
# Below, we display the `infer_df` DataFrame. This augmented dataset now includes both the actual demand (`demand`) and the model's predictions (`predicted_demand`). By examining this table, we can get a quick sense of how well our model's predictions align with the actual demand values.

# %%
infer_df
# Out:
#                            date  average_temperature   rainfall  weekend  \
# 0    2011-10-02 01:12:54.501886            30.584727   1.199291        1
# 1    2011-10-03 01:12:54.501886            15.465069   1.037626        0
# 2    2011-10-04 01:12:54.501885            10.786525   5.656089        0
# 3    2011-10-05 01:12:54.501885            23.648154  12.030937        0
# 4    2011-10-06 01:12:54.501884            13.861391   4.303812        0
# ...                         ...                  ...        ...      ...
# 4995 2025-06-05 01:12:54.498911            21.643051   3.821656        0
# 4996 2025-06-06 01:12:54.498911            13.808813   1.080603        0
# 4997 2025-06-07 01:12:54.498910            11.698227   1.911000        1
# 4998 2025-06-08 01:12:54.498908            18.052081   1.000521        1
# 4999 2025-06-09 01:12:54.498905            17.017294   0.650213        0
#
#       holiday  price_per_kg  promo       demand  previous_days_demand  \
# 0           0      1.726258      1  1351.375336           1351.276659
# 1           0      0.576471      1  1106.855943           1351.276659
# 2           0      2.513328      1  1008.304909           1106.836626
# 3           0      1.839225      1   999.833810           1057.895424
# 4           0      1.531772      1  1183.949061           1048.961007
# ...       ...           ...    ...          ...                   ...
# 4995        0      2.391010      0  1165.882437           1170.799278
# 4996        1      0.898693      0  1312.870527           1215.125948
# 4997        0      2.839860      0  1413.065524           1312.128382
# 4998        0      1.188440      0  1823.886638           1462.323379
# 4999        0      2.131694      0  1289.584771           1823.144493
#
#       competitor_price_per_kg  marketing_intensity  predicted_demand
# 0                    1.935346             0.098677       1632.068848
# 1                    2.344720             0.019318       1299.310303
# 2                    0.998803             0.409485       1200.993042
# 3                    0.761740             0.872803       1201.093872
# 4                    2.123436             0.820779       1287.853638
# ...                       ...                  ...               ...
# 4995                 1.504432             0.756489       1051.276001
# 4996                 1.343586             0.742145       1186.464844
# 4997                 2.771896             0.742145       1373.584473
# 4998                 2.564075             0.742145       1508.579468
# 4999                 0.785727             0.833140       1154.477051
#
# [5000 rows x 12 columns]

# %% [markdown]
# #### Wrapping Up: Reflecting on Our Comprehensive Machine Learning Workflow
#
# Throughout this guide, we embarked on a detailed exploration of an end-to-end machine learning workflow. We began with data preprocessing, delved deeply into hyperparameter tuning with Optuna, leveraged MLflow for structured experiment tracking, and concluded with batch inference.
#
# ##### Key Takeaways:
#
# - **Hyperparameter Tuning with Optuna**: We harnessed the power of Optuna to systematically search for the best hyperparameters for our XGBoost model, aiming to optimize its performance.
#
# - **Structured Experiment Tracking with MLflow**: MLflow's capabilities shone through as we logged experiments, metrics, parameters, and artifacts. We also explored the benefits of nested child runs, allowing us to logically group and structure our experiment iterations.
#
# - **Model Interpretation**: Various plots and metrics equipped us with insights into our model's behavior. We learned to appreciate its strengths and identify potential areas for refinement.
#
# - **Batch Inference**: The nuances of batch predictions on extensive datasets were explored, alongside methods to seamlessly integrate these predictions back into our primary data.
#
# - **Logging Visual Artifacts**: A significant portion of our journey emphasized the importance of logging visual artifacts, like plots, to MLflow. These visuals serve as invaluable references, capturing the state of the model, its performance, and any alterations to the feature set that might sway the model's performance metrics.
#
# By the end of this guide, you should possess a robust understanding of a well-structured machine learning workflow. This foundation not only empowers you to craft effective models but also ensures that each step, from data wrangling to predictions, is transparent, reproducible, and efficient.
#
# We're grateful you accompanied us on this comprehensive journey. The practices and insights gleaned will undoubtedly be pivotal in all your future machine learning endeavors!
