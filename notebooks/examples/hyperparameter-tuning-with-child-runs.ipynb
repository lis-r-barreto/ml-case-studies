# %% [markdown]
# # MLflow with Optuna: Hyperparameter Optimization and Tracking
#
# A critical part of building production-grade models is ensuring that a given model's parameters are selected to create the best inference set possible. However, the sheer number of combinations and their resultant metrics can become overwhelming to track manually. That's where tools like MLflow and Optuna come into play.
#
# ### Objective:
# In this notebook, you'll learn how to integrate MLflow with Optuna for hyperparameter optimization. We'll guide you through the process of:
#
# * Setting up your environment with MLflow tracking.
# * Generating our training and evaluation data sets.
# * Defining a partial function that fits a machine learning model.
# * Using Optuna for hyperparameter tuning.
# * Leveraging child runs within MLflow to keep track of each iteration during the hyperparameter tuning process.
#
# ### Why Optuna?
# Optuna is an open-source hyperparameter optimization framework in Python. It provides an efficient approach to searching over hyperparameters, incorporating the latest research and techniques. With its integration into MLflow, every trial can be systematically recorded.
#
# ### Child Runs in MLflow:
# One of the core features we will be emphasizing is the concept of 'child runs' in MLflow. When performing hyperparameter tuning, each iteration (or trial) in Optuna can be considered a 'child run'. This allows us to group all the runs under one primary 'parent run', ensuring that the MLflow UI remains organized and interpretable. Each child run will track the specific hyperparameters used and the resulting metrics, providing a consolidated view of the entire optimization process.
#
# ### What's Ahead?
#
# **Data Preparation**: We'll start by loading and preprocessing our dataset.
#
# **Model Definition**: Defining a machine learning model that we aim to optimize.
#
# **Optuna Study**: Setting up an Optuna study to find the best hyperparameters for our model.
#
# **MLflow Integration**: Tracking each Optuna trial as a child run in MLflow.
#
# **Analysis**: Reviewing the tracked results in the MLflow UI.
#
# By the end of this notebook, you'll have hands-on experience in setting up an advanced hyperparameter tuning workflow, emphasizing best practices and clean organization using MLflow and Optuna.
#
# **Let's dive in!**

# %%
import math
from datetime import datetime, timedelta

import numpy as np
import optuna
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow

# %% [markdown]
# ### Configure the tracking server uri
#
# Depending on where you are running this notebook, your configuration may vary for how you initialize the interface with the MLflow Tracking Server.
#
# For this example, we're using a locally running tracking server, but other options are available (The easiest is to use the free managed service within [Databricks Free Trial](https://mlflow.org/docs/latest/getting-started/databricks-trial.html)).
#
# Please see [the guide to running notebooks here](https://www.mlflow.org/docs/latest/getting-started/running-notebooks/) for more information on setting the tracking server uri and configuring access to either managed or self-managed MLflow tracking servers.

# %%
# NOTE: review the links mentioned above for guidance on connecting to a managed tracking server, such as the Databricks managed MLflow

mlflow.set_tracking_uri("http://localhost:5000")

# %% [markdown]
# ### Generate our synthetic training data
#
# If you've followed along with the introductory tutorial "Logging your first model with MLflow", then you're familiar with the apples sales data generator that we created for that tutorial.
#
# Here, we're expanding upon the data to create a slightly more complex dataset that should have improved correlation effects between the features and the target variable (the demand).

# %%
def generate_apple_sales_data_with_promo_adjustment(
    base_demand: int = 1000,
    n_rows: int = 5000,
    competitor_price_effect: float = -50.0,
):
    """
    Generates a synthetic dataset for predicting apple sales demand with multiple
    influencing factors.

    This function creates a pandas DataFrame with features relevant to apple sales.
    The features include date, average_temperature, rainfall, weekend flag, holiday flag,
    promotional flag, price_per_kg, competitor's price, marketing intensity, stock availability,
    and the previous day's demand. The target variable, 'demand', is generated based on a
    combination of these features with some added noise.

    Args:
        base_demand (int, optional): Base demand for apples. Defaults to 1000.
        n_rows (int, optional): Number of rows (days) of data to generate. Defaults to 5000.
        competitor_price_effect (float, optional): Effect of competitor's price being lower
                                                   on our sales. Defaults to -50.

    Returns:
        pd.DataFrame: DataFrame with features and target variable for apple sales prediction.

    Example:
        >>> df = generate_apple_sales_data_with_promo_adjustment(base_demand=1200, n_rows=6000)
        >>> df.head()
    """

    # Set seed for reproducibility
    np.random.seed(9999)

    # Create date range
    dates = [datetime.now() - timedelta(days=i) for i in range(n_rows)]
    dates.reverse()

    # Generate features
    df = pd.DataFrame(
        {
            "date": dates,
            "average_temperature": np.random.uniform(10, 35, n_rows),
            "rainfall": np.random.exponential(5, n_rows),
            "weekend": [(date.weekday() >= 5) * 1 for date in dates],
            "holiday": np.random.choice([0, 1], n_rows, p=[0.97, 0.03]),
            "price_per_kg": np.random.uniform(0.5, 3, n_rows),
            "month": [date.month for date in dates],
        }
    )

    # Introduce inflation over time (years)
    df["inflation_multiplier"] = 1 + (df["date"].dt.year - df["date"].dt.year.min()) * 0.03

    # Incorporate seasonality due to apple harvests
    df["harvest_effect"] = np.sin(2 * np.pi * (df["month"] - 3) / 12) + np.sin(
        2 * np.pi * (df["month"] - 9) / 12
    )

    # Modify the price_per_kg based on harvest effect
    df["price_per_kg"] = df["price_per_kg"] - df["harvest_effect"] * 0.5

    # Adjust promo periods to coincide with periods lagging peak harvest by 1 month
    peak_months = [4, 10]  # months following the peak availability
    df["promo"] = np.where(
        df["month"].isin(peak_months),
        1,
        np.random.choice([0, 1], n_rows, p=[0.85, 0.15]),
    )

    # Generate target variable based on features
    base_price_effect = -df["price_per_kg"] * 50
    seasonality_effect = df["harvest_effect"] * 50
    promo_effect = df["promo"] * 200

    df["demand"] = (
        base_demand
        + base_price_effect
        + seasonality_effect
        + promo_effect
        + df["weekend"] * 300
        + np.random.normal(0, 50, n_rows)
    ) * df["inflation_multiplier"]  # adding random noise

    # Add previous day's demand
    df["previous_days_demand"] = df["demand"].shift(1)
    df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row

    # Introduce competitor pricing
    df["competitor_price_per_kg"] = np.random.uniform(0.5, 3, n_rows)
    df["competitor_price_effect"] = (
        df["competitor_price_per_kg"] < df["price_per_kg"]
    ) * competitor_price_effect

    # Stock availability based on past sales price (3 days lag with logarithmic decay)
    log_decay = -np.log(df["price_per_kg"].shift(3) + 1) + 2
    df["stock_available"] = np.clip(log_decay, 0.7, 1)

    # Marketing intensity based on stock availability
    # Identify where stock is above threshold
    high_stock_indices = df[df["stock_available"] > 0.95].index

    # For each high stock day, increase marketing intensity for the next week
    for idx in high_stock_indices:
        df.loc[idx : min(idx + 7, n_rows - 1), "marketing_intensity"] = np.random.uniform(0.7, 1)

    # If the marketing_intensity column already has values, this will preserve them;
    #  if not, it sets default values
    fill_values = pd.Series(np.random.uniform(0, 0.5, n_rows), index=df.index)
    df["marketing_intensity"].fillna(fill_values, inplace=True)

    # Adjust demand with new factors
    df["demand"] = df["demand"] + df["competitor_price_effect"] + df["marketing_intensity"]

    # Drop temporary columns
    df.drop(
        columns=[
            "inflation_multiplier",
            "harvest_effect",
            "month",
            "competitor_price_effect",
            "stock_available",
        ],
        inplace=True,
    )

    return df

# %%
df = generate_apple_sales_data_with_promo_adjustment(base_demand=1_000, n_rows=5000)
df
# Out:
# /tmp/ipykernel_616/1129670120.py:85: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row
#                            date  average_temperature   rainfall  weekend  \
# 0    2011-10-02 00:46:52.568521            30.584727   1.199291        1
# 1    2011-10-03 00:46:52.568520            15.465069   1.037626        0
# 2    2011-10-04 00:46:52.568519            10.786525   5.656089        0
# 3    2011-10-05 00:46:52.568518            23.648154  12.030937        0
# 4    2011-10-06 00:46:52.568517            13.861391   4.303812        0
# ...                         ...                  ...        ...      ...
# 4995 2025-06-05 00:46:52.563709            21.643051   3.821656        0
# 4996 2025-06-06 00:46:52.563708            13.808813   1.080603        0
# 4997 2025-06-07 00:46:52.563708            11.698227   1.911000        1
# 4998 2025-06-08 00:46:52.563706            18.052081   1.000521        1
# 4999 2025-06-09 00:46:52.563702            17.017294   0.650213        0
#
#       holiday  price_per_kg  promo       demand  previous_days_demand  \
# 0           0      1.726258      1  1351.375336           1351.276659
# 1           0      0.576471      1  1106.855943           1351.276659
# 2           0      2.513328      1  1008.304909           1106.836626
# 3           0      1.839225      1   999.833810           1057.895424
# 4           0      1.531772      1  1183.949061           1048.961007
# ...       ...           ...    ...          ...                   ...
# 4995        0      2.391010      0  1165.882437           1170.799278
# 4996        1      0.898693      0  1312.870527           1215.125948
# 4997        0      2.839860      0  1413.065524           1312.128382
# 4998        0      1.188440      0  1823.886638           1462.323379
# 4999        0      2.131694      0  1289.584771           1823.144493
#
#       competitor_price_per_kg  marketing_intensity
# 0                    1.935346             0.098677
# 1                    2.344720             0.019318
# 2                    0.998803             0.409485
# 3                    0.761740             0.872803
# 4                    2.123436             0.820779
# ...                       ...                  ...
# 4995                 1.504432             0.756489
# 4996                 1.343586             0.742145
# 4997                 2.771896             0.742145
# 4998                 2.564075             0.742145
# 4999                 0.785727             0.833140
#
# [5000 rows x 11 columns]

# %% [markdown]
# ### Examining Feature-Target Correlations
#
# Before delving into the model building process, it's essential to understand the relationships between our features and the target variable. The upcoming function will display a plot indicating the correlation coefficient for each feature in relation to the target. Here's why this step is crucial:
#
# 1. **Avoiding Data Leakage**: We must ensure that no feature perfectly correlates with the target (a correlation coefficient of 1.0). If such a correlation exists, it's a sign that our dataset might be "leaking" information about the target. Using such data for hyperparameter tuning would mislead the model, as it could easily achieve a perfect score without genuinely learning the underlying patterns.
#
# 2. **Ensuring Meaningful Relationships**: Ideally, our features should have some degree of correlation with the target. If all features have correlation coefficients close to zero, it suggests a weak linear relationship. Although this doesn't automatically render the features useless, it does introduce challenges:
#     * *Predictive Power*: The model might struggle to make accurate predictions.
#     * *Overfitting Risk*: With weak correlations, there's a heightened risk of the model fitting to noise rather than genuine patterns, leading to overfitting.
#     * *Complexity*: Demonstrating non-linear relationships or interactions between features would necessitate more intricate visualizations and evaluations.
# 3. **Auditing and Traceability**: Logging this correlation visualization with our main MLflow run ensures traceability. It provides a snapshot of the data characteristics at the time of the model training, which is invaluable for auditing and replicability purposes.
#
# As we proceed, remember that while understanding correlations is a powerful tool, it's just one piece of the puzzle. Let's visualize these relationships to gain more insights!

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_correlation_with_demand(df, save_path=None):  # noqa: D417
    """
    Plots the correlation of each variable in the dataframe with the 'demand' column.

    Args:
    - df (pd.DataFrame): DataFrame containing the data, including a 'demand' column.
    - save_path (str, optional): Path to save the generated plot. If not specified, plot won't be saved.

    Returns:
    - None (Displays the plot on a Jupyter window)
    """

    # Compute correlations between all variables and 'demand'
    correlations = df.corr()["demand"].drop("demand").sort_values()

    # Generate a color palette from red to green
    colors = sns.diverging_palette(10, 130, as_cmap=True)
    color_mapped = correlations.map(colors)

    # Set Seaborn style
    sns.set_style(
        "whitegrid", {"axes.facecolor": "#c2c4c2", "grid.linewidth": 1.5}
    )  # Light grey background and thicker grid lines

    # Create bar plot
    fig = plt.figure(figsize=(12, 8))
    plt.barh(correlations.index, correlations.values, color=color_mapped)

    # Set labels and title with increased font size
    plt.title("Correlation with Demand", fontsize=18)
    plt.xlabel("Correlation Coefficient", fontsize=16)
    plt.ylabel("Variable", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(axis="x")

    plt.tight_layout()

    # Save the plot if save_path is specified
    if save_path:
        plt.savefig(save_path, format="png", dpi=600)

    # prevent matplotlib from displaying the chart every time we call this function
    plt.close(fig)

    return fig


# Test the function
correlation_plot = plot_correlation_with_demand(df, save_path="correlation_plot.png")

# %% [markdown]
# #### Investigating Feature Correlation with the Target Variable
#
# In the code above, we've intentionally disabled the automatic display of the plot generated by Matplotlib. During machine learning experimentation, it's often not useful to display figures directly within the notebook for several reasons. Instead, we aim to associate this plot with the results of an iterative experiment run. To achieve this, we'll save the plot to our MLflow tracking system. This provides us with a detailed record, linking the state of the dataset to the logged model, its parameters, and performance metrics.
#
# ##### Why Not Display Plots Directly in the Notebook?
#
# Choosing not to display plots within the notebook is a deliberate decision, and the reasons are multiple. Some of the key points include:
#
# - **Ephemerality of Notebooks**: Notebooks are inherently transient; they are not designed to be a permanent record of your work.
#
# - **Risk of Obsolescence**: If you rerun portions of your notebook, the plot displayed could become outdated or misleading, posing a risk when interpreting results.
#
# - **Loss of Previous State**: If you happen to rerun the entire notebook, the plot will be lost. While some plugins can recover previous cell states, setting this up can be cumbersome and time-consuming.
#
# In contrast, logging the plot to MLflow ensures that we have a permanent, easily accessible record that correlates directly with other experiment data. This is invaluable for maintaining the integrity and reproducibility of your machine learning experiments.
#
# ##### Displaying the Plot for This Guide
#
# For the purposes of this guide, we'll still take a moment to examine the plot. We can do this by explicitly calling the figure object we've returned from our function.

# %%
correlation_plot

# %% [markdown]
# #### Visualizing Model Residuals for Diagnostic Insights
#
# The `plot_residuals` function serves to visualize the residuals—the differences between the model's predictions and the actual values in the validation set. Residual plots are crucial diagnostic tools in machine learning, as they can reveal patterns that suggest our model is either failing to capture some aspect of the data or that there's a systematic issue with the model itself.
#
# ##### Why Residual Plots?
#
# Residual plots offer several advantages:
#
# - **Identifying Bias**: If residuals show a trend (not centered around zero), it might indicate that your model is systematically over- or under-predicting the target variable.
#
# - **Heteroskedasticity**: Varying spread of residuals across the range of the predicted values can indicate 'Heteroskedasticity,' which can violate assumptions in some modeling techniques.
#
# - **Outliers**: Points far away from the zero line can be considered as outliers and might warrant further investigation.
#
# ##### Auto-saving the Plot
#
# Just like with the correlation plot, this function allows you to save the residual plot to a specific path. This feature aligns with our broader strategy of logging important figures to MLflow for more effective model tracking and auditing.
#
# ##### Plot Structure
#
# In the scatter plot, each point represents the residual for a specific observation in the validation set. The red horizontal line at zero serves as a reference, indicating where residuals would lie if the model's predictions were perfect.
#
# For the sake of this guide, we will be generating this plot, but not examining it until later when we see it within the MLflow UI.

# %%
def plot_residuals(model, dvalid, valid_y, save_path=None):  # noqa: D417
    """
    Plots the residuals of the model predictions against the true values.

    Args:
    - model: The trained XGBoost model.
    - dvalid (xgb.DMatrix): The validation data in XGBoost DMatrix format.
    - valid_y (pd.Series): The true values for the validation set.
    - save_path (str, optional): Path to save the generated plot. If not specified, plot won't be saved.

    Returns:
    - None (Displays the residuals plot on a Jupyter window)
    """

    # Predict using the model
    preds = model.predict(dvalid)

    # Calculate residuals
    residuals = valid_y - preds

    # Set Seaborn style
    sns.set_style("whitegrid", {"axes.facecolor": "#c2c4c2", "grid.linewidth": 1.5})

    # Create scatter plot
    fig = plt.figure(figsize=(12, 8))
    plt.scatter(valid_y, residuals, color="blue", alpha=0.5)
    plt.axhline(y=0, color="r", linestyle="-")

    # Set labels, title and other plot properties
    plt.title("Residuals vs True Values", fontsize=18)
    plt.xlabel("True Values", fontsize=16)
    plt.ylabel("Residuals", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(axis="y")

    plt.tight_layout()

    # Save the plot if save_path is specified
    if save_path:
        plt.savefig(save_path, format="png", dpi=600)

    # Show the plot
    plt.close(fig)

    return fig

# %% [markdown]
# #### Understanding Feature Importance with XGBoost
#
# The `plot_feature_importance` function is designed to visualize the importance of each feature used in our XGBoost model. Understanding feature importance can offer critical insights into the model's decision-making process and can aid in feature selection, engineering, and interpretation.
#
# ##### Types of Feature Importance
#
# XGBoost offers multiple ways to interpret feature importance. This function supports:
#
# - **Weight**: Number of times a feature appears in a tree across the ensemble of trees (for `gblinear` booster).
# - **Gain**: Average gain (or improvement to the model) of the feature when it is used in trees (for other booster types).
#
# We automatically select the appropriate importance type based on the booster used in the XGBoost model.
#
# ##### Why Feature Importance Matters
#
# Understanding feature importance offers several advantages:
#
# - **Interpretability**: Knowing which features are most influential helps us understand the model better.
# - **Feature Selection**: Unimportant features can potentially be dropped to simplify the model.
# - **Domain Understanding**: Aligns the model's importance scale with domain-specific knowledge or intuition.
#
# ##### Saving and Accessing the Plot
#
# This function returns a Matplotlib figure object that you can further manipulate or save. Like the previous plots, it is advisable to log this plot in MLflow for an immutable record of your model's interpretive characteristics.
#
# ##### Navigating the Plot
#
# In the resulting plot, each bar represents a feature used in the model. The length of the bar corresponds to the feature's importance, as calculated by the selected importance type.
#
# We need a model to be trained in order to generate this plot. As such, we'll be generating, but not displaying the plot when we train the model. The resulting figure will be logged to MLflow and visible within the UI.

# %%
def plot_feature_importance(model, booster):  # noqa: D417
    """
    Plots feature importance for an XGBoost model.

    Args:
    - model: A trained XGBoost model

    Returns:
    - fig: The matplotlib figure object
    """
    fig, ax = plt.subplots(figsize=(10, 8))
    importance_type = "weight" if booster == "gblinear" else "gain"
    xgb.plot_importance(
        model,
        importance_type=importance_type,
        ax=ax,
        title=f"Feature Importance based on {importance_type}",
    )
    plt.tight_layout()
    plt.close(fig)

    return fig

# %% [markdown]
# ### Setting Up the MLflow Experiment
#
# Before we start our hyperparameter tuning process, we need to designate a specific "experiment" within MLflow to track and log our results. An experiment in MLflow is essentially a named set of runs. Each run within an experiment tracks its own parameters, metrics, tags, and artifacts.
#
# #### Why create a new experiment?
#
# 1. **Organization**: It helps in keeping our runs organized under a specific task or project, making it easier to compare and analyze results.
# 2. **Isolation**: By isolating different tasks or projects into separate experiments, we prevent accidental overwrites or misinterpretations of results.
#
# The `get_or_create_experiment` function we've defined below aids in this process. It checks if an experiment with the specified name already exists. If yes, it retrieves its ID. If not, it creates a new experiment and returns its ID.
#
# #### How will we use the experiment_id?
# The retrieved or created experiment_id becomes crucial when we initiate our hyperparameter tuning. As we start the parent run for tuning, the experiment_id ensures that the run, along with its nested child runs, gets logged under the correct experiment. It provides a structured way to navigate, compare, and analyze our tuning results within the MLflow UI.
#
# When we want to try additional parameter ranges, different parameters, or a slightly modified dataset, we can use this Experiment to log all parent runs to keep our MLflow Tracking UI clean and easy to navigate.
#
# Let's proceed and set up our experiment!

# %%
def get_or_create_experiment(experiment_name):
    """
    Retrieve the ID of an existing MLflow experiment or create a new one if it doesn't exist.

    This function checks if an experiment with the given name exists within MLflow.
    If it does, the function returns its ID. If not, it creates a new experiment
    with the provided name and returns its ID.

    Parameters:
    - experiment_name (str): Name of the MLflow experiment.

    Returns:
    - str: ID of the existing or newly created MLflow experiment.
    """

    if experiment := mlflow.get_experiment_by_name(experiment_name):
        return experiment.experiment_id
    else:
        return mlflow.create_experiment(experiment_name)

# %% [markdown]
# #### Create an experiment for our hyperparameter tuning runs

# %%
experiment_id = get_or_create_experiment("Apples Demand")

# %% [markdown]
# We can view the `experiment_id` that was either generated or fetched to see how this unique reference key looks. The value generated here is also visible within the MLflow UI.

# %%
experiment_id
# Out:
# '671527703213651607'

# %% [markdown]
# #### Setting Up MLflow and Data Preprocessing for Model Training
#
# This section of the code accomplishes two major tasks: initializing an MLflow experiment for usage in run tracking and preparing the dataset for model training and validation.
#
# ##### MLflow Initialization
#
# We start by setting the MLflow experiment using the `set_experiment` function. The `experiment_id` serves as a unique identifier for the experiment, allowing us to segregate and manage different runs and their associated data efficiently.
#
# ##### Data Preprocessing
#
# The next steps involve preparing the dataset for model training:
#
# 1. **Feature Selection**: We drop the columns 'date' and 'demand' from our DataFrame, retaining only the feature columns in `X`.
#
# 2. **Target Variable**: The 'demand' column is designated as our target variable `y`.
#
# 3. **Data Splitting**: We split the dataset into training (`train_x`, `train_y`) and validation (`valid_x`, `valid_y`) sets using a 75-25 split.
#
# 4. **XGBoost Data Format**: Finally, we convert the training and validation datasets into XGBoost's DMatrix format. This optimized data structure speeds up the training process and is required for using XGBoost's advanced functionalities.
#
# ##### Why These Steps Matter
#
# - **MLflow Tracking**: Initializing the MLflow experiment ensures that all subsequent model runs, metrics, and artifacts are logged under the same experiment, making it easier to compare and analyze different models. While we are using the ``fluent API`` to do this here, you can also specify the ``experiment_id`` within a ``start_run()`` context.
#
# - **Data Preparation**: Properly preparing your data ensures that the model training process will proceed without issues and that the results will be as accurate as possible.
#
# In the next steps, we'll proceed to model training and evaluation, and all these preparation steps will come into play.

# %%
# Set the current active MLflow experiment
mlflow.set_experiment(experiment_id=experiment_id)

# Preprocess the dataset
X = df.drop(columns=["date", "demand"])
y = df["demand"]
train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.25)
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x, label=valid_y)

# %% [markdown]
# #### Hyperparameter Tuning and Model Training using Optuna and MLflow
#
# The `objective` function serves as the core of our hyperparameter tuning process using Optuna. Additionally, it trains an XGBoost model using the selected hyperparameters and logs metrics and parameters to MLflow.
#
# ##### MLflow Nested Runs
#
# The function starts a new nested run in MLflow. Nested runs are useful for organizing hyperparameter tuning experiments as they allow you to group individual runs under a parent run.
#
# ##### Defining Hyperparameters
#
# Optuna's `trial.suggest_*` methods are used to define a range of possible values for hyperparameters. Here's what each hyperparameter does:
#
# - `objective` and `eval_metric`: Define the loss function and evaluation metric.
# - `booster`: Type of boosting to be used (`gbtree`, `gblinear`, or `dart`).
# - `lambda` and `alpha`: Regularization parameters.
# - Additional parameters like `max_depth`, `eta`, and `gamma` are specific to tree-based models (`gbtree` and `dart`).
#
# ##### Model Training
#
# An XGBoost model is trained using the chosen hyperparameters and the preprocessed training dataset (`dtrain`). Predictions are made on the validation set (`dvalid`), and the mean squared error (`mse`) is calculated.
#
# ##### Logging with MLflow
#
# All the selected hyperparameters and metrics (`mse` and `rmse`) are logged to MLflow for later analysis and comparison.
#
# - `mlflow.log_params`: Logs the hyperparameters.
# - `mlflow.log_metric`: Logs the metrics.
#
# ##### Why This Function is Important
#
# - **Automated Tuning**: Optuna automates the process of finding the best hyperparameters.
# - **Experiment Tracking**: MLflow allows us to keep track of each run's hyperparameters and performance metrics, making it easier to analyze, compare, and reproduce experiments later.
#
# In the next step, this objective function will be used by Optuna to find the optimal set of hyperparameters for our XGBoost model.

# %% [markdown]
# #### Housekeeping: Streamlining Logging for Optuna Trials
#
# As we embark on our hyperparameter tuning journey with Optuna, it's essential to understand that the process can generate a multitude of runs. In fact, so many that the standard output (stdout) from the default logger can quickly become inundated, producing pages upon pages of log reports.
#
# While the verbosity of the default logging configuration is undeniably valuable during the code development phase, initiating a full-scale trial can result in an overwhelming amount of information. Considering this, logging every single detail to stdout becomes less practical, especially when we have dedicated tools like MLflow to meticulously track our experiments.
#
# To strike a balance, we'll utilize callbacks to tailor our logging behavior.
#
# ##### Implementing a Logging Callback:
#
# The callback we're about to introduce will modify the default reporting behavior. Instead of logging every trial, we'll only receive updates when a new hyperparameter combination yields an improvement over the best metric value recorded thus far.
#
# This approach offers two salient benefits:
#
# 1. **Enhanced Readability**: By filtering out the extensive log details and focusing only on the trials that show improvement, we can gauge the efficacy of our hyperparameter search. For instance, if we observe a diminishing frequency of 'best result' reports early on, it might suggest that fewer iterations would suffice to pinpoint an optimal hyperparameter set. On the other hand, a consistent rate of improvement might indicate that our feature set requires further refinement.
#
# 2. **Progress Indicators**: Especially pertinent for extensive trials that span hours or even days, receiving periodic updates provides assurance that the process is still in motion. These 'heartbeat' notifications affirm that our system is diligently at work, even if it's not flooding stdout with every minute detail.
#
# Moreover, MLflow's user interface (UI) complements this strategy. As each trial concludes, MLflow logs the child run, making it accessible under the umbrella of the parent run.
#
# In the ensuing code, we:
#
# 1. Adjust Optuna's logging level to report only errors, ensuring a decluttered stdout.
# 2. Define a `champion_callback` function, tailored to log only when a trial surpasses the previously recorded best metric.
#
# Let's dive into the implementation:

# %%
# override Optuna's default logging to ERROR only
optuna.logging.set_verbosity(optuna.logging.ERROR)

# define a logging callback that will report on only new challenger parameter configurations if a
# trial has usurped the state of 'best conditions'


def champion_callback(study, frozen_trial):
    """
    Logging callback that will report when a new trial iteration improves upon existing
    best trial values.

    Note: This callback is not intended for use in distributed computing systems such as Spark
    or Ray due to the micro-batch iterative implementation for distributing trials to a cluster's
    workers or agents.
    The race conditions with file system state management for distributed trials will render
    inconsistent values with this callback.
    """

    winner = study.user_attrs.get("winner", None)

    if study.best_value and winner != study.best_value:
        study.set_user_attr("winner", study.best_value)
        if winner:
            improvement_percent = (abs(winner - study.best_value) / study.best_value) * 100
            print(
                f"Trial {frozen_trial.number} achieved value: {frozen_trial.value} with "
                f"{improvement_percent: .4f}% improvement"
            )
        else:
            print(f"Initial trial {frozen_trial.number} achieved value: {frozen_trial.value}")

# %%
def objective(trial):
    with mlflow.start_run(nested=True):
        # Define hyperparameters
        params = {
            "objective": "reg:squarederror",
            "eval_metric": "rmse",
            "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
            "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
            "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        }

        if params["booster"] == "gbtree" or params["booster"] == "dart":
            params["max_depth"] = trial.suggest_int("max_depth", 1, 9)
            params["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
            params["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
            params["grow_policy"] = trial.suggest_categorical(
                "grow_policy", ["depthwise", "lossguide"]
            )

        # Train XGBoost model
        bst = xgb.train(params, dtrain)
        preds = bst.predict(dvalid)
        error = mean_squared_error(valid_y, preds)

        # Log to MLflow
        mlflow.log_params(params)
        mlflow.log_metric("mse", error)
        mlflow.log_metric("rmse", math.sqrt(error))

    return error

# %% [markdown]
# #### Orchestrating Hyperparameter Tuning, Model Training, and Logging with MLflow
#
# This section of the code serves as the orchestration layer, bringing together Optuna for hyperparameter tuning and MLflow for experiment tracking.
#
# ##### Initiating Parent Run
#
# We begin by starting a parent MLflow run with the name "Best Run". All subsequent operations, including Optuna's trials, are nested under this parent run, providing a structured way to organize our experiments.
#
# ##### Hyperparameter Tuning with Optuna
#
# - `study = optuna.create_study(direction='minimize')`: We create an Optuna study object aiming to minimize our objective function.
# - `study.optimize(objective, n_trials=10)`: The `objective` function is optimized over 10 trials.
#
# ##### Logging Best Parameters and Metrics
#
# After Optuna finds the best hyperparameters, we log these, along with the best mean squared error (`mse`) and root mean squared error (`rmse`), to MLflow.
#
# ##### Logging Additional Metadata
#
# Using `mlflow.set_tags`, we log additional metadata like the project name, optimization engine, model family, and feature set version. This helps in better categorizing and understanding the context of the model run.
#
# ##### Model Training and Artifact Logging
#
# - We train an XGBoost model using the best hyperparameters.
# - Various plots—correlation with demand, feature importance, and residuals—are generated and logged as artifacts in MLflow.
#
# ##### Model Serialization and Logging
#
# Finally, the trained model is logged to MLflow using `mlflow.xgboost.log_model`, along with an example input and additional metadata. The model is stored in a specified artifact path and its URI is retrieved.
#
# ##### Why This Block is Crucial
#
# - **End-to-End Workflow**: This code block represents an end-to-end machine learning workflow, from hyperparameter tuning to model evaluation and logging.
# - **Reproducibility**: All details about the model, including hyperparameters, metrics, and visual diagnostics, are logged, ensuring that the experiment is fully reproducible.
# - **Analysis and Comparison**: With all data logged in MLflow, it becomes easier to analyze the performance of various runs and choose the best model for deployment.
#
# In the next steps, we'll explore how to retrieve and use the logged model for inference.

# %% [markdown]
# #### Setting a Descriptive Name for the Model Run
#
# Before proceeding with model training and hyperparameter tuning, it's beneficial to assign a descriptive name to our MLflow run. This name serves as a human-readable identifier, making it easier to track, compare, and analyze different runs.
#
# ##### The Importance of Naming Runs:
#
# - **Reference by Name**: While MLflow provides unique identifying keys like `run_id` for each run, having a descriptive name allows for more intuitive referencing, especially when using particular APIs and navigating the MLflow UI.
#
# - **Clarity and Context**: A well-chosen run name can provide context about the hypothesis being tested or the specific modifications made, aiding in understanding the purpose and rationale of a particular run.
#
# - **Automatic Naming**: If you don't specify a run name, MLflow will generate a unique fun name for you. However, this might lack the context and clarity of a manually chosen name.
#
# ##### Best Practices:
#
# When naming your runs, consider the following:
#
# 1. **Relevance to Code Changes**: The name should reflect any code or parameter modifications made for that run.
# 2. **Iterative Runs**: If you're executing multiple runs iteratively, it's a good idea to update the run name for each iteration to avoid confusion.
#
# In the subsequent steps, we will set a name for our parent run. Remember, if you execute the model training multiple times, consider updating the run name for clarity.

# %%
run_name = "first_attempt"

# %%
# Initiate the parent run and call the hyperparameter tuning child run logic
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name, nested=True):
    # Initialize the Optuna study
    study = optuna.create_study(direction="minimize")

    # Execute the hyperparameter optimization trials.
    # Note the addition of the `champion_callback` inclusion to control our logging
    study.optimize(objective, n_trials=500, callbacks=[champion_callback])

    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_mse", study.best_value)
    mlflow.log_metric("best_rmse", math.sqrt(study.best_value))

    # Log tags
    mlflow.set_tags(
        tags={
            "project": "Apple Demand Project",
            "optimizer_engine": "optuna",
            "model_family": "xgboost",
            "feature_set_version": 1,
        }
    )

    # Log a fit model instance
    model = xgb.train(study.best_params, dtrain)

    # Log the correlation plot
    mlflow.log_figure(figure=correlation_plot, artifact_file="correlation_plot.png")

    # Log the feature importances plot
    importances = plot_feature_importance(model, booster=study.best_params.get("booster"))
    mlflow.log_figure(figure=importances, artifact_file="feature_importances.png")

    # Log the residuals plot
    residuals = plot_residuals(model, dvalid, valid_y)
    mlflow.log_figure(figure=residuals, artifact_file="residuals.png")

    artifact_path = "model_artifacts"

    mlflow.xgboost.log_model(
        xgb_model=model,
        artifact_path=artifact_path,
        input_example=train_x.iloc[[0]],
        model_format="ubj",
        metadata={"model_data_version": 1},
    )

    # Get the logged model uri so that we can load it from the artifact store
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# 🏃 View run popular-snail-607 at: http://localhost:5000/#/experiments/671527703213651607/runs/55b92ed2fbb94f93bfe157979860bfca
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Initial trial 0 achieved value: 63073.437406603385
# 🏃 View run fearless-crab-294 at: http://localhost:5000/#/experiments/671527703213651607/runs/c781afdf2a924b4bab0f40daf34d1d4f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run angry-quail-471 at: http://localhost:5000/#/experiments/671527703213651607/runs/7cd1d1a072684d3f952838f585800f6f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-shad-596 at: http://localhost:5000/#/experiments/671527703213651607/runs/17790b8a00ed416da4625f15f8272182
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 3 achieved value: 26267.028752855484 with  140.1240% improvement
# 🏃 View run sassy-gnu-826 at: http://localhost:5000/#/experiments/671527703213651607/runs/09bed98358e540cabe0e84a9fd07eb3e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run trusting-robin-152 at: http://localhost:5000/#/experiments/671527703213651607/runs/e46813000d0044d8930c15d2436d8aaa
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 5 achieved value: 19429.46746409094 with  35.1917% improvement
# 🏃 View run victorious-ox-317 at: http://localhost:5000/#/experiments/671527703213651607/runs/6fff0aa12569436a99035d80c7488496
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run calm-trout-867 at: http://localhost:5000/#/experiments/671527703213651607/runs/262da298ba6348758b49e0b90b8a1c17
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fortunate-frog-664 at: http://localhost:5000/#/experiments/671527703213651607/runs/64d4ae6736e747d8b5f58c5c597db8da
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thoughtful-tern-936 at: http://localhost:5000/#/experiments/671527703213651607/runs/cf2f31a1a9044a94bfe1a74ac00c2e8b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 9 achieved value: 19409.095787231807 with  0.1050% improvement
# 🏃 View run unique-grub-575 at: http://localhost:5000/#/experiments/671527703213651607/runs/776b403802f24746b37ab855bcc690b5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 10 achieved value: 19409.01112376964 with  0.0004% improvement
# 🏃 View run bright-zebra-26 at: http://localhost:5000/#/experiments/671527703213651607/runs/4b103d77b51a4a09bf08168e8c2bfbc1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 11 achieved value: 19408.4127390706 with  0.0031% improvement
# 🏃 View run skillful-duck-825 at: http://localhost:5000/#/experiments/671527703213651607/runs/af9f7dc33da24724a8459c22c120cdeb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run brawny-calf-171 at: http://localhost:5000/#/experiments/671527703213651607/runs/e28562c354e14b46b7cc88d55c6322b7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capricious-rook-342 at: http://localhost:5000/#/experiments/671527703213651607/runs/7458dad44ffc4651965dcc8e5858731b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nimble-robin-185 at: http://localhost:5000/#/experiments/671527703213651607/runs/5556c511b90a45db95aeb42a4e626316
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adventurous-cod-319 at: http://localhost:5000/#/experiments/671527703213651607/runs/4560d8ba343c4e35ac10ca2e34863aba
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run illustrious-bat-358 at: http://localhost:5000/#/experiments/671527703213651607/runs/7e6f35dd8e13420293dfa358da4ba9f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-colt-948 at: http://localhost:5000/#/experiments/671527703213651607/runs/5e35af0e122e40d1a53f1485c0f0e0f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run gifted-goose-712 at: http://localhost:5000/#/experiments/671527703213651607/runs/073414b46ee54289b143421425eea20c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thoughtful-asp-493 at: http://localhost:5000/#/experiments/671527703213651607/runs/1c127d99b3854c65bceb1d65d3d83dba
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run illustrious-fish-806 at: http://localhost:5000/#/experiments/671527703213651607/runs/139bb6f27afb4b6386cc57c9e5563e53
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run colorful-flea-101 at: http://localhost:5000/#/experiments/671527703213651607/runs/5b40509a5fb3477fb3e5ca6ad3a4cdf2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run tasteful-gull-605 at: http://localhost:5000/#/experiments/671527703213651607/runs/a98ff5a3b68844d8a98ef5ad8dd9f811
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 23 achieved value: 19321.348135644566 with  0.4506% improvement
# 🏃 View run abundant-sponge-506 at: http://localhost:5000/#/experiments/671527703213651607/runs/98f429823f554cc5a097da13a00dc39e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nimble-midge-442 at: http://localhost:5000/#/experiments/671527703213651607/runs/2d7f948af46d4058814ad8588f01ca6e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run omniscient-seal-641 at: http://localhost:5000/#/experiments/671527703213651607/runs/d25c369377ad4b448e665b47566d3c38
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run merciful-cub-436 at: http://localhost:5000/#/experiments/671527703213651607/runs/b1fa19fef063489dbaebb13ffb0c4bc2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rumbling-sheep-359 at: http://localhost:5000/#/experiments/671527703213651607/runs/f96f8810b4a74cf69bd2562b2750f9df
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run blushing-foal-342 at: http://localhost:5000/#/experiments/671527703213651607/runs/cac22b7cf3b849a8858a5d7849a0288f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run traveling-jay-170 at: http://localhost:5000/#/experiments/671527703213651607/runs/dd3fb13cad0a44e0b969b920b1f914ba
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run classy-croc-735 at: http://localhost:5000/#/experiments/671527703213651607/runs/f7d0f0a3f8784f78a84e56fef25d4252
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run respected-flea-703 at: http://localhost:5000/#/experiments/671527703213651607/runs/bdc62861598a4dfca17d6a0f7f14f03a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 32 achieved value: 19179.924451283605 with  0.7374% improvement
# 🏃 View run wistful-newt-359 at: http://localhost:5000/#/experiments/671527703213651607/runs/46755d8e19e24cbfbb5362a041bead1e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run lyrical-cow-829 at: http://localhost:5000/#/experiments/671527703213651607/runs/86c27209b452459380f8c629ee8cb018
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run trusting-conch-697 at: http://localhost:5000/#/experiments/671527703213651607/runs/8f59ae473082422c9281a88bd69869c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 35 achieved value: 16784.804063269796 with  14.2696% improvement
# 🏃 View run respected-sponge-637 at: http://localhost:5000/#/experiments/671527703213651607/runs/62aefeb77edc49fa8cd2c9318d31d3be
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 36 achieved value: 16665.56498722334 with  0.7155% improvement
# 🏃 View run big-swan-370 at: http://localhost:5000/#/experiments/671527703213651607/runs/52740bbb13c94112bb9ee4d0e2d9eb19
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upbeat-boar-47 at: http://localhost:5000/#/experiments/671527703213651607/runs/8a0c033d19e14806aa3ef8a77494e65a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-foal-59 at: http://localhost:5000/#/experiments/671527703213651607/runs/6c739ddda0814aa086ab12b5d4cc4cb9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run smiling-chimp-125 at: http://localhost:5000/#/experiments/671527703213651607/runs/171c83dec84a49a6a725f49849528aff
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sassy-goat-28 at: http://localhost:5000/#/experiments/671527703213651607/runs/ab8e616423564e74aa584542eaa9cc26
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rogue-lamb-427 at: http://localhost:5000/#/experiments/671527703213651607/runs/739b5e52dbda40d2ad080fe32d66354a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 42 achieved value: 16360.963432753697 with  1.8618% improvement
# 🏃 View run bemused-bee-591 at: http://localhost:5000/#/experiments/671527703213651607/runs/60ef2937d7a8409f9c413c9457777e92
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dashing-goose-891 at: http://localhost:5000/#/experiments/671527703213651607/runs/91f716a0e0964693b65d67effa246f08
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-pug-585 at: http://localhost:5000/#/experiments/671527703213651607/runs/591ca42596c9460c9cb0e51f82cead2b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 45 achieved value: 16359.568635561061 with  0.0085% improvement
# 🏃 View run adventurous-wolf-835 at: http://localhost:5000/#/experiments/671527703213651607/runs/64565fa7c3574cf38a3873c2240127fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run resilient-kit-736 at: http://localhost:5000/#/experiments/671527703213651607/runs/d8e368e1cec74b0e90960c6f6087d74f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rebellious-asp-853 at: http://localhost:5000/#/experiments/671527703213651607/runs/616b68b3c969436b85e54250ef251051
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 48 achieved value: 15902.47317526074 with  2.8744% improvement
# 🏃 View run likeable-sheep-499 at: http://localhost:5000/#/experiments/671527703213651607/runs/b263ea187aea4fc9b829aad99582cadc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 49 achieved value: 15371.732226983539 with  3.4527% improvement
# 🏃 View run kindly-shad-89 at: http://localhost:5000/#/experiments/671527703213651607/runs/336bf7842d714173b4fb23bf79e37e0c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run puzzled-newt-963 at: http://localhost:5000/#/experiments/671527703213651607/runs/4cbcb00039314ed79ac07a16d47b8ddd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run orderly-shrike-547 at: http://localhost:5000/#/experiments/671527703213651607/runs/b34bd94df1a74dd0a93b1dfb8f770b44
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run puzzled-shoat-211 at: http://localhost:5000/#/experiments/671527703213651607/runs/a38844787a5247d8a7271093a1c824e6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run righteous-perch-521 at: http://localhost:5000/#/experiments/671527703213651607/runs/cd85530d13054c0fb3b78fc70eab36b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run painted-bear-24 at: http://localhost:5000/#/experiments/671527703213651607/runs/26a67e5a0c1f460885d32361541d33df
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run welcoming-cat-667 at: http://localhost:5000/#/experiments/671527703213651607/runs/d8a9ceb04a234b9292a2d8442c7e884a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-ox-100 at: http://localhost:5000/#/experiments/671527703213651607/runs/601f3e159a2e413e93bf379997776147
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enthused-sheep-48 at: http://localhost:5000/#/experiments/671527703213651607/runs/838a8ac8189a4cffb8b83546c72d444b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run zealous-hen-920 at: http://localhost:5000/#/experiments/671527703213651607/runs/045694579e2b4c97a44f6fe99927aed1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run stylish-fly-609 at: http://localhost:5000/#/experiments/671527703213651607/runs/74d2ce858fa846ca9f3e4db37058a31d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wise-cat-641 at: http://localhost:5000/#/experiments/671527703213651607/runs/d467f49c84fb47299e86be02e09b85d0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abrasive-hare-523 at: http://localhost:5000/#/experiments/671527703213651607/runs/4e909b52525e4b13bc7ba2d745892d82
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fearless-perch-691 at: http://localhost:5000/#/experiments/671527703213651607/runs/f8c2195e43d04866b2c71d6461be5592
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run carefree-turtle-315 at: http://localhost:5000/#/experiments/671527703213651607/runs/901ea77b372442179e7d89824c0bd97b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run omniscient-shark-566 at: http://localhost:5000/#/experiments/671527703213651607/runs/08876ad2e2dd45f2b2e919b10570ef57
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fearless-bug-627 at: http://localhost:5000/#/experiments/671527703213651607/runs/530d131e4329451bb973800545e7b1d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rumbling-ox-919 at: http://localhost:5000/#/experiments/671527703213651607/runs/fc8969444b62429abadc7e8ff7035417
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run calm-elk-704 at: http://localhost:5000/#/experiments/671527703213651607/runs/1f2035a1b70b4fe18168f7ee36ced675
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run big-grub-895 at: http://localhost:5000/#/experiments/671527703213651607/runs/e092ae6afae9442299e1830f4c02813b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run colorful-cow-451 at: http://localhost:5000/#/experiments/671527703213651607/runs/503d0b153a1a4e02b1f2846e232a5970
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run crawling-whale-825 at: http://localhost:5000/#/experiments/671527703213651607/runs/79b643141fad4688a3ddcf4095ec345a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run suave-doe-105 at: http://localhost:5000/#/experiments/671527703213651607/runs/c861f1eb9e5b4f3a940a26f27193086d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run aged-cub-415 at: http://localhost:5000/#/experiments/671527703213651607/runs/e760f090b33c429d9455b89ee0f5e407
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run trusting-snake-950 at: http://localhost:5000/#/experiments/671527703213651607/runs/5219fefb396243ec9a3e358bcbe4bfdb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abundant-loon-344 at: http://localhost:5000/#/experiments/671527703213651607/runs/eac9b7931e7e45bbae5d98b2a1c9ab73
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 75 achieved value: 15240.457286731287 with  0.8614% improvement
# 🏃 View run ambitious-bear-466 at: http://localhost:5000/#/experiments/671527703213651607/runs/60408f812cfe43c78c41169d280b5710
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upset-grub-550 at: http://localhost:5000/#/experiments/671527703213651607/runs/11738f93765e4f48a7cb4a157df1c06b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abrasive-cub-320 at: http://localhost:5000/#/experiments/671527703213651607/runs/8a642dea40de4f8baadc78603b55ba03
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run omniscient-toad-680 at: http://localhost:5000/#/experiments/671527703213651607/runs/94334a141190428f9b64397bfde5fa85
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wistful-toad-959 at: http://localhost:5000/#/experiments/671527703213651607/runs/dc4c6cd47b9748fd8d119a57729db0db
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enchanting-moth-582 at: http://localhost:5000/#/experiments/671527703213651607/runs/0e34cbf2ef6c4fa491a571f18b906414
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run respected-elk-451 at: http://localhost:5000/#/experiments/671527703213651607/runs/a02bf1fb5366469e85bc60e7ebf6b6d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skillful-robin-611 at: http://localhost:5000/#/experiments/671527703213651607/runs/9e8a58226b11419e91ba7a4407f38bc2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nebulous-steed-36 at: http://localhost:5000/#/experiments/671527703213651607/runs/5fd48729f242422395bfc284ebc98848
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wistful-hog-531 at: http://localhost:5000/#/experiments/671527703213651607/runs/80bb789bc48447b597e7798ce09465a1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run calm-bird-582 at: http://localhost:5000/#/experiments/671527703213651607/runs/adb3fd0950b84b1687930197bf3d19ac
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bold-horse-31 at: http://localhost:5000/#/experiments/671527703213651607/runs/d5cdbdedbd5448aba5cff29cfdd764d9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mercurial-loon-624 at: http://localhost:5000/#/experiments/671527703213651607/runs/8108a123907347aeba6a24e63e2ab423
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rambunctious-pig-693 at: http://localhost:5000/#/experiments/671527703213651607/runs/d9b60bb404be4db192c227a918d6c623
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dazzling-bear-218 at: http://localhost:5000/#/experiments/671527703213651607/runs/98fb8da5a2534e3aad6632c2b15b5969
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upbeat-foal-458 at: http://localhost:5000/#/experiments/671527703213651607/runs/2c451c9b69bf4af5b8c593a3256f49f0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run magnificent-worm-880 at: http://localhost:5000/#/experiments/671527703213651607/runs/3296931c0ea7443d9be25d40e7f10824
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bold-rat-436 at: http://localhost:5000/#/experiments/671527703213651607/runs/b64b6056b52b4e579d5103e2f5717be4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bemused-ox-283 at: http://localhost:5000/#/experiments/671527703213651607/runs/9bc1f0699fb04324a204a48af4a9bdec
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unruly-sow-901 at: http://localhost:5000/#/experiments/671527703213651607/runs/bd9bd68836834c789c0769b9ef7bdc56
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run caring-shad-585 at: http://localhost:5000/#/experiments/671527703213651607/runs/81f0ceacb1f54fbeb5cc5353886114de
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unique-steed-204 at: http://localhost:5000/#/experiments/671527703213651607/runs/d656eb2a966b4803ae16ad8585cd0b64
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run serious-quail-486 at: http://localhost:5000/#/experiments/671527703213651607/runs/70d4f0f14fd94e359d3049f0fe23c2b5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run efficient-fly-709 at: http://localhost:5000/#/experiments/671527703213651607/runs/53c43764ca2e4f21853ec37edad64321
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run efficient-hound-604 at: http://localhost:5000/#/experiments/671527703213651607/runs/ab18e202c5d84d63b62198e862cf4a0d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run valuable-bat-919 at: http://localhost:5000/#/experiments/671527703213651607/runs/692e035f3c624461a4b6db53086bf4b4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fortunate-toad-285 at: http://localhost:5000/#/experiments/671527703213651607/runs/472891f0d4424aa4af730c0d53627936
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delicate-stork-116 at: http://localhost:5000/#/experiments/671527703213651607/runs/41dc083643ad411a8fad25d45269d957
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run treasured-gnu-891 at: http://localhost:5000/#/experiments/671527703213651607/runs/6ee626f37a784240974b77bada1fd695
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abrasive-shark-468 at: http://localhost:5000/#/experiments/671527703213651607/runs/aebe6462be814621b089b871452fc919
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run honorable-bee-589 at: http://localhost:5000/#/experiments/671527703213651607/runs/f8e2487715ad4e9d9da8da0219e17bba
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run carefree-skunk-862 at: http://localhost:5000/#/experiments/671527703213651607/runs/839af0359e564bc0b254e7d60c4cffef
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thundering-hare-827 at: http://localhost:5000/#/experiments/671527703213651607/runs/ac05af9ed95d4cd7b2089116853bc8fa
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run awesome-ox-673 at: http://localhost:5000/#/experiments/671527703213651607/runs/f4d086f3097d401d9ba26436136bb258
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run ambitious-hound-599 at: http://localhost:5000/#/experiments/671527703213651607/runs/cbb66203d6574b1cad5934a50e29c8ed
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rogue-shark-70 at: http://localhost:5000/#/experiments/671527703213651607/runs/1ee573cdf96047e7add00acdcda43ed7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run shivering-sheep-217 at: http://localhost:5000/#/experiments/671527703213651607/runs/7f0df36d31a047749d19d18bde126b16
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nosy-stork-879 at: http://localhost:5000/#/experiments/671527703213651607/runs/00da0f9d8bbb4fb48dbd634f90049efb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sincere-cat-844 at: http://localhost:5000/#/experiments/671527703213651607/runs/6dab8227ab7d497490cd5f59618c2e24
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run invincible-horse-320 at: http://localhost:5000/#/experiments/671527703213651607/runs/2dddd8afcd3a43b7948684df12681693
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run stylish-sow-531 at: http://localhost:5000/#/experiments/671527703213651607/runs/fb60e55092be4ab79589bc20da8aae5e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dapper-gnu-174 at: http://localhost:5000/#/experiments/671527703213651607/runs/5e001c30f77e4d8b83d36d3e9070965c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run silent-grouse-253 at: http://localhost:5000/#/experiments/671527703213651607/runs/bbe91f0829884cca80a4349db90210f6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run trusting-newt-647 at: http://localhost:5000/#/experiments/671527703213651607/runs/54877f2953ec4ca4b289a287b864fccd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-bear-305 at: http://localhost:5000/#/experiments/671527703213651607/runs/9783bbc521704a708dca564329b4c76d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sincere-conch-189 at: http://localhost:5000/#/experiments/671527703213651607/runs/df6dcfe948bd4f00aa1e0c98afd985af
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run efficient-calf-383 at: http://localhost:5000/#/experiments/671527703213651607/runs/045efd843ebe429891d399e298673353
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run masked-boar-650 at: http://localhost:5000/#/experiments/671527703213651607/runs/5c2d9e717a124f9895723d321830e1df
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-cod-402 at: http://localhost:5000/#/experiments/671527703213651607/runs/26421d37bade49ddb9b0c2a1e079c9d6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 124 achieved value: 15196.752450703805 with  0.2876% improvement
# 🏃 View run grandiose-rat-947 at: http://localhost:5000/#/experiments/671527703213651607/runs/5f4325c583fb4e08a9d02036057432f3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bittersweet-hog-90 at: http://localhost:5000/#/experiments/671527703213651607/runs/80548525b490491783074d6671847712
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run silent-ape-41 at: http://localhost:5000/#/experiments/671527703213651607/runs/e05d02c188cb4125b7c4200cac3f444e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run peaceful-carp-518 at: http://localhost:5000/#/experiments/671527703213651607/runs/a181f29e3ac246629cb0bcb400087cd5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run vaunted-turtle-450 at: http://localhost:5000/#/experiments/671527703213651607/runs/f0d0f7c82e0b49f98ae20e373dbe67b8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run respected-cub-412 at: http://localhost:5000/#/experiments/671527703213651607/runs/8457ef009ef94a259abb05638df4328f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run colorful-sponge-356 at: http://localhost:5000/#/experiments/671527703213651607/runs/0d95f8b6824f40a6855056c81a8e61c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nosy-midge-795 at: http://localhost:5000/#/experiments/671527703213651607/runs/ee5092647cfe410aa146d94569d13538
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run funny-ox-230 at: http://localhost:5000/#/experiments/671527703213651607/runs/8d5dd78e28d14dfc954f78a61480e7fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-conch-398 at: http://localhost:5000/#/experiments/671527703213651607/runs/166547a6a2d34dfca880d609ea9244af
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run popular-asp-909 at: http://localhost:5000/#/experiments/671527703213651607/runs/e38e166589ee430abf229b854c3e45b5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-skink-222 at: http://localhost:5000/#/experiments/671527703213651607/runs/988b2adfcabe4a9294a0faaf568917cd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run powerful-fly-93 at: http://localhost:5000/#/experiments/671527703213651607/runs/7bb0202f7e704ef3843786834433deed
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run indecisive-shrike-54 at: http://localhost:5000/#/experiments/671527703213651607/runs/e942bba8e9384b81a74cf665d1b2524d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run judicious-dog-486 at: http://localhost:5000/#/experiments/671527703213651607/runs/ea2d2ca49da64ad1b47e28a2dfba7249
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sassy-bug-775 at: http://localhost:5000/#/experiments/671527703213651607/runs/f6a96242052642d88a404a8648b41846
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run casual-tern-888 at: http://localhost:5000/#/experiments/671527703213651607/runs/de3252ee154e46349914b3cc284f54ea
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amusing-hawk-345 at: http://localhost:5000/#/experiments/671527703213651607/runs/afe792e0ec9444c0a7313d4fa37d2d43
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amusing-snake-451 at: http://localhost:5000/#/experiments/671527703213651607/runs/661aae0c292148a7acb0ff958c4aa1d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run invincible-shrimp-69 at: http://localhost:5000/#/experiments/671527703213651607/runs/538447a89aa0497e8810c5afc2074e0d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rare-rook-275 at: http://localhost:5000/#/experiments/671527703213651607/runs/8e848f0ff4da425ebfdfd008a3e33a6b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run treasured-hare-981 at: http://localhost:5000/#/experiments/671527703213651607/runs/fc0ace3b6f8d401091d2da3b601846af
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run youthful-cod-248 at: http://localhost:5000/#/experiments/671527703213651607/runs/c9071e78b65f4129b65454ed82e92484
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unique-gnu-760 at: http://localhost:5000/#/experiments/671527703213651607/runs/95f22ebe62a64d49b530e092351cc0c1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run illustrious-frog-893 at: http://localhost:5000/#/experiments/671527703213651607/runs/2ec1369f927e45cd84414899cb09660a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run powerful-jay-187 at: http://localhost:5000/#/experiments/671527703213651607/runs/b2c656b8978c4441b1fbf24b3571692d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adorable-fish-638 at: http://localhost:5000/#/experiments/671527703213651607/runs/46a1dfcc2046416e83cc15323fd4e33a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run agreeable-stoat-779 at: http://localhost:5000/#/experiments/671527703213651607/runs/445d46ccbfda41c88e27cbc51f42625d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run learned-stork-181 at: http://localhost:5000/#/experiments/671527703213651607/runs/ea714ceaf3d34e6b89dfd614f2f124aa
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run agreeable-stork-155 at: http://localhost:5000/#/experiments/671527703213651607/runs/90edfa19f67b4f68b842119bfff60ac1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run mysterious-goat-39 at: http://localhost:5000/#/experiments/671527703213651607/runs/cd973aaad3b24661968d31815b88e3d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run invincible-worm-816 at: http://localhost:5000/#/experiments/671527703213651607/runs/6e0c03d574564a478504871d09f90a7c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capable-mouse-512 at: http://localhost:5000/#/experiments/671527703213651607/runs/9bb03fbe690747c8bc66aa13e14cd9f8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# Trial 157 achieved value: 15155.586645029993 with  0.2716% improvement
# 🏃 View run funny-sow-848 at: http://localhost:5000/#/experiments/671527703213651607/runs/7e459294902a4c9090bd6f24f013fddd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skittish-tern-360 at: http://localhost:5000/#/experiments/671527703213651607/runs/562d6029672e4939aee27a2fa9629dc8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run vaunted-dove-609 at: http://localhost:5000/#/experiments/671527703213651607/runs/37f1449bab334e39b46f799b2da263d2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run lyrical-steed-695 at: http://localhost:5000/#/experiments/671527703213651607/runs/fc6f0bc3dd164ae283465364b70707b1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run inquisitive-mole-195 at: http://localhost:5000/#/experiments/671527703213651607/runs/279ff07e52b540ed8ff6277cc53c4fe8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run gregarious-fawn-773 at: http://localhost:5000/#/experiments/671527703213651607/runs/00371168ea334912b5782bc88d8df36b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run beautiful-crow-318 at: http://localhost:5000/#/experiments/671527703213651607/runs/903df280be0d441ab345ebfc44ddf10c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run illustrious-shad-249 at: http://localhost:5000/#/experiments/671527703213651607/runs/94e1a4a7bf9048309185ad08fb8e9d26
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run suave-colt-934 at: http://localhost:5000/#/experiments/671527703213651607/runs/0d756e4a68fc44269430a54c90ebc6d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bemused-sheep-782 at: http://localhost:5000/#/experiments/671527703213651607/runs/b4f8a130b47c41d68ae791af5e3222b1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run adaptable-asp-527 at: http://localhost:5000/#/experiments/671527703213651607/runs/ffac1dd5ca794d41a92ee154485a9390
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run spiffy-lynx-462 at: http://localhost:5000/#/experiments/671527703213651607/runs/b63a89ed9e944f1292ebf5ff95d8c34a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bedecked-asp-798 at: http://localhost:5000/#/experiments/671527703213651607/runs/fcfc0babb2f04cdaa8276e5195016afc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-wasp-767 at: http://localhost:5000/#/experiments/671527703213651607/runs/fbdc1212e45e43aea60b0be0074cc5ff
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run placid-hound-153 at: http://localhost:5000/#/experiments/671527703213651607/runs/f8b389b0b5fe4efbb0dfdde427018c8d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amusing-grouse-223 at: http://localhost:5000/#/experiments/671527703213651607/runs/9a76cab502094151b7ce31f6d5e28a39
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dazzling-colt-448 at: http://localhost:5000/#/experiments/671527703213651607/runs/808d36eaf5e44c6f86eb076f9ce8be3c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run learned-grouse-117 at: http://localhost:5000/#/experiments/671527703213651607/runs/0ffcc57547cf49cb865c306f84cbae3f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run inquisitive-cub-288 at: http://localhost:5000/#/experiments/671527703213651607/runs/71d36a5d21c34693889db4b1d9aac041
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thundering-bee-555 at: http://localhost:5000/#/experiments/671527703213651607/runs/c15c054442d247e0ba7a48c3e658581f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run invincible-lark-774 at: http://localhost:5000/#/experiments/671527703213651607/runs/fa900e736d85476eae4e015af6577468
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rogue-ray-363 at: http://localhost:5000/#/experiments/671527703213651607/runs/87b10ccabbe2446a8bed4759cbeea8e6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run enthused-jay-282 at: http://localhost:5000/#/experiments/671527703213651607/runs/ff9d668ff4a64b2fb78a3b833f3f70b3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fun-mole-822 at: http://localhost:5000/#/experiments/671527703213651607/runs/04fc09151cdc47a69766e36117591534
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wise-gnat-639 at: http://localhost:5000/#/experiments/671527703213651607/runs/0380689b4c8b4c61919e30fb818e409c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-midge-895 at: http://localhost:5000/#/experiments/671527703213651607/runs/54fbd45971d84268832e7c53a2148fe7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run orderly-toad-168 at: http://localhost:5000/#/experiments/671527703213651607/runs/a8e562fa40bc456ea8de741b9ab92308
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-koi-228 at: http://localhost:5000/#/experiments/671527703213651607/runs/76b7a06b4cdd4bddb17e7884e9686ebd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run efficient-slug-270 at: http://localhost:5000/#/experiments/671527703213651607/runs/bc9e6f1d7fe046c6bb4a31b0634993a1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run placid-ray-306 at: http://localhost:5000/#/experiments/671527703213651607/runs/0df88178f4ac4e209ac923b1c53946eb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run marvelous-doe-522 at: http://localhost:5000/#/experiments/671527703213651607/runs/b8172767eeee455faf5df7c8cc1bfdb6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run indecisive-squid-777 at: http://localhost:5000/#/experiments/671527703213651607/runs/77f91a89df324f5dbde8a424e21bf074
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run trusting-wolf-17 at: http://localhost:5000/#/experiments/671527703213651607/runs/56dbcfb9a4bc4fc8a024fc160eee434f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run grandiose-dove-334 at: http://localhost:5000/#/experiments/671527703213651607/runs/3d730eb1369a4c0996976f0b5493761e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dapper-owl-355 at: http://localhost:5000/#/experiments/671527703213651607/runs/4606f78f96814076847ae246109f8989
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run merciful-trout-146 at: http://localhost:5000/#/experiments/671527703213651607/runs/86f90e7b251f4c1ba14dd4b7bb7e2846
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skillful-slug-863 at: http://localhost:5000/#/experiments/671527703213651607/runs/0482ca36e71748acaf07683848bc1ded
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wistful-colt-556 at: http://localhost:5000/#/experiments/671527703213651607/runs/8de8d840f781416ea54f34bacec82688
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thoughtful-cat-280 at: http://localhost:5000/#/experiments/671527703213651607/runs/5e5b2e77defa4a1582bc89fa982740d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unleashed-snipe-478 at: http://localhost:5000/#/experiments/671527703213651607/runs/1fb10fe85a144483bfb79b9da26549fc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unleashed-hare-569 at: http://localhost:5000/#/experiments/671527703213651607/runs/4ed519ca46414e67a14b0c535f64eaf8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-tern-18 at: http://localhost:5000/#/experiments/671527703213651607/runs/155c73bbc1064b6bb720dda400b58e3e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run resilient-sloth-88 at: http://localhost:5000/#/experiments/671527703213651607/runs/872229131d894da5b0b8cc4d3640f830
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run secretive-pig-936 at: http://localhost:5000/#/experiments/671527703213651607/runs/fb5f663393cd49f9beecca588d8843da
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nebulous-eel-239 at: http://localhost:5000/#/experiments/671527703213651607/runs/d9a983e651ee4f36b4960d49ba04a25c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run youthful-hog-808 at: http://localhost:5000/#/experiments/671527703213651607/runs/d9a643a5ada340da9857c6968b9108b1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run flawless-doe-695 at: http://localhost:5000/#/experiments/671527703213651607/runs/afb0f4a2cf0b43ff9fcf7a991a643421
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run gaudy-tern-621 at: http://localhost:5000/#/experiments/671527703213651607/runs/67a85c3a701b405db9c03c167a94f719
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run receptive-stoat-332 at: http://localhost:5000/#/experiments/671527703213651607/runs/264082f1e38b4b4b9669756975daf2dc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-stork-358 at: http://localhost:5000/#/experiments/671527703213651607/runs/c25234e056e9444aa0e57ddd7eafccab
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run zealous-kite-133 at: http://localhost:5000/#/experiments/671527703213651607/runs/75d347ef05d24b43b0b66be712114ef6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rumbling-squid-373 at: http://localhost:5000/#/experiments/671527703213651607/runs/8114b0e1520e416fad7ede2d822fd1fc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run brawny-owl-43 at: http://localhost:5000/#/experiments/671527703213651607/runs/ed98777fec4a416fbfbc9d34f5754768
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run useful-doe-167 at: http://localhost:5000/#/experiments/671527703213651607/runs/47f4c02074a24301a7393d109c2bcbf8
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run respected-loon-197 at: http://localhost:5000/#/experiments/671527703213651607/runs/05075fb08283464080ef3ce0d2dfea7e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run silent-pug-865 at: http://localhost:5000/#/experiments/671527703213651607/runs/135e57b044974e9280679eb4e7d7a54a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run crawling-gnu-421 at: http://localhost:5000/#/experiments/671527703213651607/runs/6969bc849cac4443a92c990eee542b7e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-ox-669 at: http://localhost:5000/#/experiments/671527703213651607/runs/d221bb072f1b489e8b834b22e6bc7b18
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run merciful-lynx-705 at: http://localhost:5000/#/experiments/671527703213651607/runs/427ba6f7fa2147c6992b91719e3a498f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-flea-74 at: http://localhost:5000/#/experiments/671527703213651607/runs/fbbb85e95fc84637836a068c4c6ec39c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run treasured-panda-962 at: http://localhost:5000/#/experiments/671527703213651607/runs/4483eb94511b4ea8a6f1b04beb2711c2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-squid-786 at: http://localhost:5000/#/experiments/671527703213651607/runs/771027c9d5874013b8074920e62cdb0a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run likeable-bird-948 at: http://localhost:5000/#/experiments/671527703213651607/runs/a8cd09ea18d84fcdb795312865e636cc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skillful-horse-186 at: http://localhost:5000/#/experiments/671527703213651607/runs/86dbab5580ce4d7297174b72dd80310c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fearless-wolf-904 at: http://localhost:5000/#/experiments/671527703213651607/runs/e0fe0bdfe2c5449f9c483817e4bf0e1d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sincere-elk-569 at: http://localhost:5000/#/experiments/671527703213651607/runs/5f46db7a7edf4f9fa98ad5d98182d173
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run receptive-roo-736 at: http://localhost:5000/#/experiments/671527703213651607/runs/23aee2ee3231487894e8979745bd792e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sedate-dove-241 at: http://localhost:5000/#/experiments/671527703213651607/runs/f43bf68ef717495b84f34c2507b593fe
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-kit-821 at: http://localhost:5000/#/experiments/671527703213651607/runs/955d403574f7474799ca391ab30ad48d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run glamorous-cub-915 at: http://localhost:5000/#/experiments/671527703213651607/runs/404afc68e5bd466abf43f35997a221d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run gentle-mole-106 at: http://localhost:5000/#/experiments/671527703213651607/runs/5702023a5c684b57a7305c0607778fef
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run whimsical-ram-160 at: http://localhost:5000/#/experiments/671527703213651607/runs/705c8e8cc91a4c369f8e9714dd6266d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run handsome-quail-492 at: http://localhost:5000/#/experiments/671527703213651607/runs/344ed8dadd5f4b3db0a7f58c3b20b096
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# ...
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run wistful-newt-916 at: http://localhost:5000/#/experiments/671527703213651607/runs/dc95789059eb48fabe24870ee99431eb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run flawless-ray-254 at: http://localhost:5000/#/experiments/671527703213651607/runs/b4475a39be014a7fba89a372af74ec8d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run chill-slug-498 at: http://localhost:5000/#/experiments/671527703213651607/runs/b3f26240e81f400eb3f2a39d795d4a42
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run salty-hen-569 at: http://localhost:5000/#/experiments/671527703213651607/runs/44002c1ae9e2430faa16a4c307cca3e1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run defiant-quail-414 at: http://localhost:5000/#/experiments/671527703213651607/runs/98ecc9a752bf4c0e8f5fed476799190c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run ambitious-shoat-621 at: http://localhost:5000/#/experiments/671527703213651607/runs/a94df003181d4f7bb63f862faa396719
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unique-gnu-281 at: http://localhost:5000/#/experiments/671527703213651607/runs/d71bee56874d4117a882e51f8736fa83
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run illustrious-foal-35 at: http://localhost:5000/#/experiments/671527703213651607/runs/d77940e73be44a96885c6e9ed59a491f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run kindly-loon-566 at: http://localhost:5000/#/experiments/671527703213651607/runs/8a52552384644d11a8ef5e85cc51955b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-tern-645 at: http://localhost:5000/#/experiments/671527703213651607/runs/16ed4c65698f42e692b100f895445298
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rambunctious-dog-536 at: http://localhost:5000/#/experiments/671527703213651607/runs/a00b81c437a04de19a0f8e2d82c09a17
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-croc-806 at: http://localhost:5000/#/experiments/671527703213651607/runs/330ebcf05ef343698a5dcd2d4649b843
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nervous-chimp-610 at: http://localhost:5000/#/experiments/671527703213651607/runs/feb9878b005f40478431385920850052
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run exultant-lark-576 at: http://localhost:5000/#/experiments/671527703213651607/runs/c69d5b3108bd4573aa22cad964757d96
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run powerful-sponge-525 at: http://localhost:5000/#/experiments/671527703213651607/runs/03a2fb6c7f2e4e668bb5ba7cc131b351
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run persistent-rook-232 at: http://localhost:5000/#/experiments/671527703213651607/runs/865e0760401a4ce1a4628ae5bcae165d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run thoughtful-quail-580 at: http://localhost:5000/#/experiments/671527703213651607/runs/c27448c3230b46ceaffc69d297542189
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-goose-357 at: http://localhost:5000/#/experiments/671527703213651607/runs/50b0ec39b0ec40a0a757a7ef3b7dc41a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run lyrical-gnu-838 at: http://localhost:5000/#/experiments/671527703213651607/runs/521e8a7755fb4ce39621e1455cd94baa
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run serious-hen-495 at: http://localhost:5000/#/experiments/671527703213651607/runs/c51971bdd44d4ee8b0cdc83800d01f9f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run resilient-hare-699 at: http://localhost:5000/#/experiments/671527703213651607/runs/3fb56c637eda4c77aae4cc0b115b77f1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run loud-sheep-19 at: http://localhost:5000/#/experiments/671527703213651607/runs/f1a370c2a11e4e1baa0128709c016fa9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run indecisive-lynx-243 at: http://localhost:5000/#/experiments/671527703213651607/runs/afdef8d64dde4e73bac942c0e2d0ffb7
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skittish-skink-553 at: http://localhost:5000/#/experiments/671527703213651607/runs/01f6c96cd690413b9cd4d27933e3200e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-eel-997 at: http://localhost:5000/#/experiments/671527703213651607/runs/2d16ddf403534e2f8c1cd4db5c1b11c6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capricious-fish-328 at: http://localhost:5000/#/experiments/671527703213651607/runs/5569efb080534f75b9a2d80c13bc735d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run crawling-smelt-231 at: http://localhost:5000/#/experiments/671527703213651607/runs/a9cfb116350e4d93b2cdc8a3c6d92c40
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sincere-bee-800 at: http://localhost:5000/#/experiments/671527703213651607/runs/c7407fa9afaf49edbd23281316e050c1
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bedecked-tern-920 at: http://localhost:5000/#/experiments/671527703213651607/runs/dd4ea2a5b52845dc991202e1132c77d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bedecked-shrike-185 at: http://localhost:5000/#/experiments/671527703213651607/runs/1ea943df9ed94500856d396bb54cb21c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run suave-fox-136 at: http://localhost:5000/#/experiments/671527703213651607/runs/1e70ce155f01419d84a979b8c86b7019
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run delicate-gnu-285 at: http://localhost:5000/#/experiments/671527703213651607/runs/f28d9c791556483090b27f872cc72211
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run suave-fox-848 at: http://localhost:5000/#/experiments/671527703213651607/runs/bd36e5a176d64784b3c609925130a92a
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-jay-665 at: http://localhost:5000/#/experiments/671527703213651607/runs/9f648cf174f2439e85376e7bc4eb3e37
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run abrasive-bug-276 at: http://localhost:5000/#/experiments/671527703213651607/runs/97cf814fe6c64f1ab371127657c0b175
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run chill-squid-576 at: http://localhost:5000/#/experiments/671527703213651607/runs/e6553d9aeae74d87a03dc0344f230017
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run chill-mole-161 at: http://localhost:5000/#/experiments/671527703213651607/runs/fa11f9c45c69488984f7e84d819d56dc
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run serious-whale-660 at: http://localhost:5000/#/experiments/671527703213651607/runs/f4837d945fda4843994a013805ed8197
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run able-midge-295 at: http://localhost:5000/#/experiments/671527703213651607/runs/abcfb6297b464b8f867cdfcf11c919ba
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run incongruous-wolf-455 at: http://localhost:5000/#/experiments/671527703213651607/runs/898f46a92b4f4d5f9981db91338cc8f6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run useful-moth-260 at: http://localhost:5000/#/experiments/671527703213651607/runs/2073bd00c2b3466cae12176e57f574a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run unruly-ray-718 at: http://localhost:5000/#/experiments/671527703213651607/runs/8d0372e359544ff3ad0fae2e6403c022
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-swan-751 at: http://localhost:5000/#/experiments/671527703213651607/runs/e201b33c4ab74ee995cbc5fc2bccba27
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run zealous-carp-7 at: http://localhost:5000/#/experiments/671527703213651607/runs/df47d49d5a3f4b2896a2c2da377788e2
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run sassy-mole-225 at: http://localhost:5000/#/experiments/671527703213651607/runs/64daf9a0195c4f408b8b04cdca4c8199
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run defiant-calf-366 at: http://localhost:5000/#/experiments/671527703213651607/runs/893a87d9f55b4f429009cf868806bbc4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run respected-kit-506 at: http://localhost:5000/#/experiments/671527703213651607/runs/dac8a808fc2045ffa0236259d29b7fc4
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run illustrious-seal-809 at: http://localhost:5000/#/experiments/671527703213651607/runs/e1b9bf99b22c44829325cc7565e93e4b
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run amazing-wolf-435 at: http://localhost:5000/#/experiments/671527703213651607/runs/b237796b77cc4d00a12cff4636006674
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run able-bass-920 at: http://localhost:5000/#/experiments/671527703213651607/runs/53483dc649074db2adb385e0f70507a3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run exultant-newt-389 at: http://localhost:5000/#/experiments/671527703213651607/runs/1166b3fa1c7049b6ad87ab4095563699
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run rambunctious-pug-589 at: http://localhost:5000/#/experiments/671527703213651607/runs/ca4bb639d0b8437eb0f765e67069c02f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run masked-shrimp-61 at: http://localhost:5000/#/experiments/671527703213651607/runs/f824e7b89195402babaef037be5da6e0
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run popular-snake-480 at: http://localhost:5000/#/experiments/671527703213651607/runs/3327cbb9d37a4a2d8121054cbe1dac83
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run redolent-snake-637 at: http://localhost:5000/#/experiments/671527703213651607/runs/a18e653b31c04b5a9bf5564303ad0854
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run omniscient-hare-830 at: http://localhost:5000/#/experiments/671527703213651607/runs/7821073ca9c3404dab3e20f18cee4699
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run auspicious-worm-345 at: http://localhost:5000/#/experiments/671527703213651607/runs/fd51f0cfaa334820a2718a968943e603
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run salty-ray-624 at: http://localhost:5000/#/experiments/671527703213651607/runs/1cf81ad029ee411cb458b4533c9d6345
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run bouncy-fawn-828 at: http://localhost:5000/#/experiments/671527703213651607/runs/9a1692ffa9124ab8b48c5f20ff4b689c
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run skittish-cat-146 at: http://localhost:5000/#/experiments/671527703213651607/runs/b855ffc69b2c4670a840d6178430195d
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run capable-steed-152 at: http://localhost:5000/#/experiments/671527703213651607/runs/2cdd7ecc670d4b209fe4212893cf2ffb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run judicious-crab-434 at: http://localhost:5000/#/experiments/671527703213651607/runs/9b26138ebb2c41beaa04224b82f661bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upset-colt-195 at: http://localhost:5000/#/experiments/671527703213651607/runs/08bacf3d0d8b4eccb7d2c31ac8a0f8cd
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run able-ox-348 at: http://localhost:5000/#/experiments/671527703213651607/runs/7cfa7dd8c1b34f3f8d84d609573e95a9
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run clumsy-cat-991 at: http://localhost:5000/#/experiments/671527703213651607/runs/bff422dd97444cfea060e19d7caffe8f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run dapper-vole-971 at: http://localhost:5000/#/experiments/671527703213651607/runs/f233e5bad3744545b94e8d955b91ad45
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run worried-fowl-362 at: http://localhost:5000/#/experiments/671527703213651607/runs/848d35009c754a31aa1e7ea49aaee0e6
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run colorful-grub-398 at: http://localhost:5000/#/experiments/671527703213651607/runs/22f868f9c981483fb142c6e289bb8201
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run upbeat-vole-245 at: http://localhost:5000/#/experiments/671527703213651607/runs/c9db82d26fb6444db1c4611ce833fdf3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run funny-stoat-768 at: http://localhost:5000/#/experiments/671527703213651607/runs/ca075576281946a4b0f1520310b4bca3
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run caring-midge-315 at: http://localhost:5000/#/experiments/671527703213651607/runs/1a9e88c7a23d492e9a2ad7c0e855c08e
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run fortunate-lark-170 at: http://localhost:5000/#/experiments/671527703213651607/runs/5f75a5afc8404125a950cf51425a010f
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run nimble-auk-154 at: http://localhost:5000/#/experiments/671527703213651607/runs/5e6636ff52b941a9bbf5f918b0799f94
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# 🏃 View run marvelous-finch-557 at: http://localhost:5000/#/experiments/671527703213651607/runs/35f9578099144db0a8a12df677894a35
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607
# /opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run first_attempt at: http://localhost:5000/#/experiments/671527703213651607/runs/2bf265a5e4154bf39a92fbbae63cc4ce
# 🧪 View experiment at: http://localhost:5000/#/experiments/671527703213651607

# %% [markdown]
# #### Understanding the Artifact URI in MLflow
#
# The output 'mlflow-artifacts:/908436739760555869/c8d64ce51f754eb698a3c09239bcdcee/artifacts/model' represents a unique Uniform Resource Identifier (URI) for the trained model artifacts within MLflow. This URI is a crucial component of MLflow's architecture, and here's why:
#
# ##### Simplified Access to Model Artifacts
#
# The `model_uri` abstracts away the underlying storage details, providing a consistent and straightforward way to reference model artifacts, regardless of where they are stored. Whether your artifacts are on a local filesystem, in a cloud storage bucket, or on a network mount, the URI remains a consistent reference point.
#
# ##### Abstraction of Storage Details
#
# MLflow is designed to be storage-agnostic. This means that while you might switch the backend storage from, say, a local directory to an Amazon S3 bucket, the way you interact with MLflow remains consistent. The URI ensures that you don't need to know the specifics of the storage backend; you only need to reference the model's URI.
#
# ##### Associated Information and Metadata
#
# Beyond just the model files, the URI provides access to associated metadata, the model artifact, and other logged artifacts (files and images). This ensures that you have a comprehensive set of information about the model, aiding in reproducibility, analysis, and deployment.
#
# ##### In Summary
#
# The `model_uri` serves as a consistent, abstracted reference to your model and its associated data. It simplifies interactions with MLflow, ensuring that users don't need to worry about the specifics of underlying storage mechanisms and can focus on the machine learning workflow.

# %%
model_uri
# Out:
# 'mlflow-artifacts:/671527703213651607/2bf265a5e4154bf39a92fbbae63cc4ce/artifacts/model_artifacts'

# %% [markdown]
# #### Loading the Trained Model with MLflow
#
# With the line:
#
# ```python
# loaded = mlflow.xgboost.load_model(model_uri)
# ```
# we're leveraging MLflow's native model loader for XGBoost. Instead of using the generic pyfunc loader, which provides a universal Python function interface for models, we're using the XGBoost-specific loader.
#
# ##### Benefits of Native Loading:
#
# - **Fidelity**: Loading the model using the native loader ensures that you're working with the exact same model object as it was during training. This means all nuances, specifics, and intricacies of the original model are preserved.
#
# - **Functionality**: With the native model object in hand, you can utilize all of its inherent methods and properties. This allows for more flexibility, especially when you need advanced features or fine-grained control during inference.
#
# - **Performance**: Using the native model object might offer performance benefits, especially when performing batch inference or deploying the model in environments optimized for the specific machine learning framework.
#
# In essence, by loading the model natively, we ensure maximum compatibility and functionality, allowing for a seamless transition from training to inference.

# %%
loaded = mlflow.xgboost.load_model(model_uri)
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# #### Example: Batch Inference Using the Loaded Model
#
# After loading the model natively, performing batch inference is straightforward.
#
# In the following cell, we're going to perform a prediction based on the entire source feature set.
# Although doing an inference action on the entire training and validation dataset features is of very limited utility in a real-world application, we'll use our generated synthetic data here to illustrate using the native model for inference.

# %% [markdown]
# #### Performing Batch Inference and Augmenting Data
#
# In this section, we're taking our entire dataset and performing batch inference using our loaded XGBoost model. We'll then append these predictions back into our original dataset to compare, analyze, or further process.
#
# ##### Steps Explained:
#
# 1. **Creating a DMatrix**: `batch_dmatrix = xgb.DMatrix(X)`: We first convert our features (`X`) into XGBoost's optimized DMatrix format. This data structure is specifically designed for efficiency and speed in XGBoost.
#
# 2. **Predictions**: `inference = loaded.predict(batch_dmatrix)`: Using the previously loaded model (`loaded`), we perform batch inference on the entire dataset.
#
# 3. **Creating a New DataFrame**: `infer_df = df.copy()`: We create a copy of the original DataFrame to ensure that we're not modifying our original data.
#
# 4. **Appending Predictions**: `infer_df["predicted_demand"] = inference`: The predictions are then added as a new column, `predicted_demand`, to this DataFrame.
#
# ##### Best Practices:
#
# - **Always Copy Data**: When augmenting or modifying datasets, it's generally a good idea to work with a copy. This ensures that the original data remains unchanged, preserving data integrity.
#
# - **Batch Inference**: When predicting on large datasets, using batch inference (as opposed to individual predictions) can offer significant speed improvements.
#
# - **DMatrix Conversion**: While converting to DMatrix might seem like an extra step, it's crucial for performance when working with XGBoost. It ensures that predictions are made as quickly as possible.
#
# In the subsequent steps, we can further analyze the differences between the actual demand and our model's predicted demand, potentially visualizing the results or calculating performance metrics.

# %%
batch_dmatrix = xgb.DMatrix(X)

inference = loaded.predict(batch_dmatrix)

infer_df = df.copy()

infer_df["predicted_demand"] = inference

# %% [markdown]
# #### Visualizing the Augmented DataFrame
#
# Below, we display the `infer_df` DataFrame. This augmented dataset now includes both the actual demand (`demand`) and the model's predictions (`predicted_demand`). By examining this table, we can get a quick sense of how well our model's predictions align with the actual demand values.

# %%
infer_df
# Out:
#                            date  average_temperature   rainfall  weekend  \
# 0    2011-10-02 00:46:52.568521            30.584727   1.199291        1
# 1    2011-10-03 00:46:52.568520            15.465069   1.037626        0
# 2    2011-10-04 00:46:52.568519            10.786525   5.656089        0
# 3    2011-10-05 00:46:52.568518            23.648154  12.030937        0
# 4    2011-10-06 00:46:52.568517            13.861391   4.303812        0
# ...                         ...                  ...        ...      ...
# 4995 2025-06-05 00:46:52.563709            21.643051   3.821656        0
# 4996 2025-06-06 00:46:52.563708            13.808813   1.080603        0
# 4997 2025-06-07 00:46:52.563708            11.698227   1.911000        1
# 4998 2025-06-08 00:46:52.563706            18.052081   1.000521        1
# 4999 2025-06-09 00:46:52.563702            17.017294   0.650213        0
#
#       holiday  price_per_kg  promo       demand  previous_days_demand  \
# 0           0      1.726258      1  1351.375336           1351.276659
# 1           0      0.576471      1  1106.855943           1351.276659
# 2           0      2.513328      1  1008.304909           1106.836626
# 3           0      1.839225      1   999.833810           1057.895424
# 4           0      1.531772      1  1183.949061           1048.961007
# ...       ...           ...    ...          ...                   ...
# 4995        0      2.391010      0  1165.882437           1170.799278
# 4996        1      0.898693      0  1312.870527           1215.125948
# 4997        0      2.839860      0  1413.065524           1312.128382
# 4998        0      1.188440      0  1823.886638           1462.323379
# 4999        0      2.131694      0  1289.584771           1823.144493
#
#       competitor_price_per_kg  marketing_intensity  predicted_demand
# 0                    1.935346             0.098677       1645.899414
# 1                    2.344720             0.019318       1299.935303
# 2                    0.998803             0.409485       1187.361816
# 3                    0.761740             0.872803       1185.318604
# 4                    2.123436             0.820779       1266.995605
# ...                       ...                  ...               ...
# 4995                 1.504432             0.756489       1046.165405
# 4996                 1.343586             0.742145       1204.506958
# 4997                 2.771896             0.742145       1378.849487
# 4998                 2.564075             0.742145       1491.511353
# 4999                 0.785727             0.833140       1159.136475
#
# [5000 rows x 12 columns]

# %% [markdown]
# #### Wrapping Up: Reflecting on Our Comprehensive Machine Learning Workflow
#
# Throughout this guide, we embarked on a detailed exploration of an end-to-end machine learning workflow. We began with data preprocessing, delved deeply into hyperparameter tuning with Optuna, leveraged MLflow for structured experiment tracking, and concluded with batch inference.
#
# ##### Key Takeaways:
#
# - **Hyperparameter Tuning with Optuna**: We harnessed the power of Optuna to systematically search for the best hyperparameters for our XGBoost model, aiming to optimize its performance.
#
# - **Structured Experiment Tracking with MLflow**: MLflow's capabilities shone through as we logged experiments, metrics, parameters, and artifacts. We also explored the benefits of nested child runs, allowing us to logically group and structure our experiment iterations.
#
# - **Model Interpretation**: Various plots and metrics equipped us with insights into our model's behavior. We learned to appreciate its strengths and identify potential areas for refinement.
#
# - **Batch Inference**: The nuances of batch predictions on extensive datasets were explored, alongside methods to seamlessly integrate these predictions back into our primary data.
#
# - **Logging Visual Artifacts**: A significant portion of our journey emphasized the importance of logging visual artifacts, like plots, to MLflow. These visuals serve as invaluable references, capturing the state of the model, its performance, and any alterations to the feature set that might sway the model's performance metrics.
#
# By the end of this guide, you should possess a robust understanding of a well-structured machine learning workflow. This foundation not only empowers you to craft effective models but also ensures that each step, from data wrangling to predictions, is transparent, reproducible, and efficient.
#
# We're grateful you accompanied us on this comprehensive journey. The practices and insights gleaned will undoubtedly be pivotal in all your future machine learning endeavors!
